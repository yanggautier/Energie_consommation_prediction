# %% [markdown]
# # Analyse Exploratoire

# %% [markdown]
# ### Importation des modules

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import joblib

from pprint import pprint
from xgboost import XGBRegressor

from sklearn.pipeline import Pipeline
from sklearn.inspection import permutation_importance

from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.model_selection import (
    train_test_split,
    GridSearchCV, 
    cross_val_score
)
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error, root_mean_squared_error 
from sklearn.inspection import permutation_importance

#Preprocess
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import LabelEncoder, OneHotEncoder, StandardScaler, MultiLabelBinarizer, FunctionTransformer

from sklearn import linear_model

#Modèles
from sklearn.dummy import DummyRegressor
from sklearn.linear_model import LinearRegression
from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor

# %% [markdown]
# ### Importation des données

# %%
building_consumption = pd.read_csv("data/2016_Building_Energy_Benchmarking.csv")
building_consumption.shape
# Out:
# (3376, 46)

# %%
building_consumption.columns.values
# Out:
# array(['OSEBuildingID', 'DataYear', 'BuildingType', 'PrimaryPropertyType',
#        'PropertyName', 'Address', 'City', 'State', 'ZipCode',
#        'TaxParcelIdentificationNumber', 'CouncilDistrictCode',
#        'Neighborhood', 'Latitude', 'Longitude', 'YearBuilt',
#        'NumberofBuildings', 'NumberofFloors', 'PropertyGFATotal',
#        'PropertyGFAParking', 'PropertyGFABuilding(s)',
#        'ListOfAllPropertyUseTypes', 'LargestPropertyUseType',
#        'LargestPropertyUseTypeGFA', 'SecondLargestPropertyUseType',
#        'SecondLargestPropertyUseTypeGFA', 'ThirdLargestPropertyUseType',
#        'ThirdLargestPropertyUseTypeGFA', 'YearsENERGYSTARCertified',
#        'ENERGYSTARScore', 'SiteEUI(kBtu/sf)', 'SiteEUIWN(kBtu/sf)',
#        'SourceEUI(kBtu/sf)', 'SourceEUIWN(kBtu/sf)',
#        'SiteEnergyUse(kBtu)', 'SiteEnergyUseWN(kBtu)', 'SteamUse(kBtu)',
#        'Electricity(kWh)', 'Electricity(kBtu)', 'NaturalGas(therms)',
#        'NaturalGas(kBtu)', 'DefaultData', 'Comments', 'ComplianceStatus',
#        'Outlier', 'TotalGHGEmissions', 'GHGEmissionsIntensity'],
#       dtype=object)

# %%
building_consumption["BuildingType"].unique()
# Out:
# array(['NonResidential', 'Nonresidential COS', 'Multifamily MR (5-9)',
#        'SPS-District K-12', 'Campus', 'Multifamily LR (1-4)',
#        'Multifamily HR (10+)', 'Nonresidential WA'], dtype=object)

# %%
building_consumption = building_consumption.loc[(building_consumption["BuildingType"] == "NonResidential") |
                                                (building_consumption["BuildingType"] == "Nonresidential COS") |
                                                (building_consumption["BuildingType"] == "Nonresidential WA")]

# %%
# Suppression des colonnes qu'on n'a pas besoin ou de string de cardinalité trop élevé
building_consumption.drop(columns=["OSEBuildingID",
                                   "City",
                                   "State",
                                   "Address",
                                   "Comments", 
                                   "PropertyName",
                                   'Longitude',
                                   'Latitude',
                                   "YearsENERGYSTARCertified",
                                   "TaxParcelIdentificationNumber",
                                   "SecondLargestPropertyUseTypeGFA", 
                                   "ThirdLargestPropertyUseTypeGFA"], inplace=True)
building_consumption.shape
# Out:
# (1546, 34)

# %%
# Suppression des colonnes qui sont basées sur la colonne de target pour éviter le data leakage
building_consumption.drop(columns=["SiteEnergyUseWN(kBtu)", 
                       'SiteEUI(kBtu/sf)', 
                       'SourceEUI(kBtu/sf)',
                       'SourceEUIWN(kBtu/sf)',
                       'SiteEUIWN(kBtu/sf)',
                       'GHGEmissionsIntensity',
                       'ENERGYSTARScore',
                       'TotalGHGEmissions'], inplace=True)
building_consumption.shape
# Out:
# (1546, 26)

# %%
# Calcul de la matrice de corrélation
corr_matrix = building_consumption.corr().abs()

# Création d'une matrice triangulaire supérieure
upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(bool))

# Identification des colonnes à supprimer
to_drop = ['PropertyGFABuilding(s)', 
           'LargestPropertyUseTypeGFA', 
           'Electricity(kBtu)', 
           'Electricity(kWh)', 
           'NaturalGas(kBtu)']

# Supprimer des colonnes trop corrélés
building_consumption.drop(columns=to_drop, inplace=True)

building_consumption.shape
# Out:
# /var/folders/b8/_p_1v95j6ql648xwdw382p9h0000gn/T/ipykernel_30052/4055215925.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr_matrix = building_consumption.corr().abs()
# (1546, 21)

# %%
building_consumption.columns.values
# Out:
# array(['DataYear', 'BuildingType', 'PrimaryPropertyType', 'ZipCode',
#        'CouncilDistrictCode', 'Neighborhood', 'YearBuilt',
#        'NumberofBuildings', 'NumberofFloors', 'PropertyGFATotal',
#        'PropertyGFAParking', 'ListOfAllPropertyUseTypes',
#        'LargestPropertyUseType', 'SecondLargestPropertyUseType',
#        'ThirdLargestPropertyUseType', 'SiteEnergyUse(kBtu)',
#        'SteamUse(kBtu)', 'NaturalGas(therms)', 'DefaultData',
#        'ComplianceStatus', 'Outlier'], dtype=object)

# %%
# Les colonnes supprimées qui ont une corrélation élevée avec les autres colonnes
print(to_drop)
# Out:
# ['PropertyGFABuilding(s)', 'LargestPropertyUseTypeGFA', 'Electricity(kBtu)', 'Electricity(kWh)', 'NaturalGas(kBtu)']

# %% [markdown]
# #### Détection des lignes qu'on n'a pas besoin

# %%
# Supprimer les lignes dont les codes postales sont vide et dont les lignes sont des outliers
building_consumption = building_consumption.loc[~building_consumption["ZipCode"].isnull(), :]

# Supprimer les lignes des années de contructions qui sont vides
building_consumption =  building_consumption.loc[~building_consumption["YearBuilt"].isnull()]

building_consumption.shape
# Out:
# (1530, 21)

# %%
# Suppression des outliers
building_consumption = building_consumption.loc[(building_consumption["PropertyGFATotal"] < 3000000) &
                                          (building_consumption["NumberofBuildings"] < 23) &
                                          (building_consumption["SteamUse(kBtu)"] < 5e+7) &
                                          (building_consumption["NaturalGas(therms)"] < 1.5e+6) &
                                          (building_consumption["Outlier"].isnull())]
building_consumption.drop('Outlier', axis=1, inplace=True)

building_consumption.shape
# Out:
# (1509, 20)

# %%
building_consumption.columns.values
# Out:
# array(['DataYear', 'BuildingType', 'PrimaryPropertyType', 'ZipCode',
#        'CouncilDistrictCode', 'Neighborhood', 'YearBuilt',
#        'NumberofBuildings', 'NumberofFloors', 'PropertyGFATotal',
#        'PropertyGFAParking', 'ListOfAllPropertyUseTypes',
#        'LargestPropertyUseType', 'SecondLargestPropertyUseType',
#        'ThirdLargestPropertyUseType', 'SiteEnergyUse(kBtu)',
#        'SteamUse(kBtu)', 'NaturalGas(therms)', 'DefaultData',
#        'ComplianceStatus'], dtype=object)

# %% [markdown]
# ###  Feature engineering

# %%
# Ajouter comme nouvelle colonne
# district_density = building_consumption.groupby('CouncilDistrictCode')['PropertyGFATotal'].mean()
# building_consumption['DistrictDensity'] = building_consumption['CouncilDistrictCode'].map(district_density)
# building_consumption["BuildingAge"] = building_consumption["DataYear"] - building_consumption["YearBuilt"]
# building_consumption['NumberofFloors'] = building_consumption['NumberofFloors'].replace(0, 1)
# building_consumption["MeanFloorGFA"] = (building_consumption["PropertyGFATotal"] / building_consumption["NumberofFloors"]).round(2)
# building_consumption["RationParking"] = (building_consumption["PropertyGFAParking"] / building_consumption["PropertyGFATotal"]).round(2)

# Changement des colonnes en type string
# building_consumption["ZipCode"] = building_consumption["ZipCode"].astype(int).astype(str)
# building_consumption["CouncilDistrictCode"] = building_consumption["CouncilDistrictCode"].astype(str)
# building_consumption["YearBuilt"] = building_consumption["YearBuilt"].astype(str)
# building_consumption.drop(columns=["DataYear"], inplace=True)

# La colonne ListOfAllPropertyUseTypes est une colonne des tags en format string qui est séparé par une virgule
# Transformer cette colonne est une colonne de liste
# building_consumption["PropertyUseTypes"] = building_consumption["ListOfAllPropertyUseTypes"].str.split(',').apply(lambda x: [tag.strip() for tag in x])

# Utilisation de cette colonne pour créer des colonnes binaire par l'intermédiaire de MultiLabelBinarizer()
# mlb = MultiLabelBinarizer()
# tags_encoded = pd.DataFrame(
#     mlb.fit_transform(building_consumption["PropertyUseTypes"]),
#     columns=mlb.classes_,
#     index=building_consumption.index
# )
# building_consumption.shape

# Changement des colonnes en type string
# building_consumption["ZipCode"] = building_consumption["ZipCode"].astype(int).astype(str)
# building_consumption["CouncilDistrictCode"] = building_consumption["CouncilDistrictCode"].astype(str)
# building_consumption["YearBuilt"] = building_consumption["YearBuilt"].astype(str)

# building_consumption.drop(columns=["DataYear"], inplace=True)

# Supprimer la colonne ListOfAllPropertyUseTypes et concaténer les colonnes crées
# df_processed = building_consumption.drop(["ListOfAllPropertyUseTypes", "PropertyUseTypes"], axis=1)
# building_consumption = pd.concat([df_processed, tags_encoded], axis=1)
# building_consumption.reset_index(drop=True, inplace=True)

# One Hot Encoding sur les années de construction
# enc = OneHotEncoder()
# labels = enc.fit_transform(building_consumption.YearBuilt.values.reshape(-1, 1)).toarray()

# Concatérner le dataset initial avec les données encodées
# encoded_df = pd.DataFrame(columns = enc.get_feature_names_out(['YearBuilt']), data = labels)
# encoded_df = encoded_df.reset_index(drop=True)
# df = pd.concat([building_consumption, encoded_df],axis = 1)
# df.drop("YearBuilt", axis=1, inplace=True)

# One Hot Encoding sur les autres colonnes
# for column in df.select_dtypes(["object"]).columns.values:
#     enc = OneHotEncoder()
#     labels = enc.fit_transform(df[column].values.reshape(-1, 1)).toarray()
#     
#     # Concatérner le dataset initial avec les données encodées
#     encoded_df = pd.DataFrame(columns = enc.get_feature_names_out([column]), data = labels)
#     encoded_df = encoded_df.reset_index(drop=True)
#     df = pd.concat([df, encoded_df],axis = 1)
#     df.drop(column, axis=1, inplace=True)
    
# Remplacer les nan par 0
# df_final = df.replace(np.nan, 0)

# %% [markdown]
# ### Création de pipeline avec les étapes de traîtement en haut

# %%
class UsageCountTransformer(BaseEstimator, TransformerMixin):
    def fit(self, X, y=None):
        return self
    
    def transform(self, X):
        X_copy = X.copy()
        X_copy['CountUsage'] = X_copy.apply(
            lambda row: sum(1 for col in ['PrimaryPropertyType', 'SecondLargestPropertyUseType', 'ThirdLargestPropertyUseType']
                          if row[col]), axis=1
        )
        return X_copy.drop(columns=['SecondLargestPropertyUseType', 'ThirdLargestPropertyUseType'])

class DistrictDensityTransformer(BaseEstimator, TransformerMixin):
    def __init__(self):
        self.district_density = None
    
    def fit(self, X, y=None):
        self.district_density = X.groupby('CouncilDistrictCode')['PropertyGFATotal'].mean()
        return self
    
    def transform(self, X):
        X_copy = X.copy()
        X_copy['DistrictDensity'] = X_copy['CouncilDistrictCode'].map(self.district_density)
        return X_copy

class FeatureEngineeringTransformer(BaseEstimator, TransformerMixin):
    def fit(self, X, y=None):
        return self
    
    def transform(self, X):
        X_copy = X.copy()
        X_copy["BuildingAge"] = X_copy["DataYear"] - X_copy["YearBuilt"]
        X_copy['NumberofFloors'] = X_copy['NumberofFloors'].replace(0, 1)
        X_copy["MeanFloorGFA"] = (X_copy["PropertyGFATotal"] / X_copy["NumberofFloors"]).round(2)
        X_copy["RationParking"] = (X_copy["PropertyGFAParking"] / X_copy["PropertyGFATotal"]).round(2)
        return X_copy

class TypeConversionTransformer(BaseEstimator, TransformerMixin):
    def fit(self, X, y=None):
        return self
    
    def transform(self, X):
        X_copy = X.copy()
        X_copy["ZipCode"] = X_copy["ZipCode"].astype(int).astype(str)
        X_copy["CouncilDistrictCode"] = X_copy["CouncilDistrictCode"].astype(str)
        X_copy["YearBuilt"] = X_copy["YearBuilt"].astype(str)
        return X_copy.drop(columns=["DataYear"])

class PropertyTypeTransformer(BaseEstimator, TransformerMixin):
    def __init__(self):
        self.mlb = MultiLabelBinarizer()
        
    def fit(self, X, y=None):
        property_types = X["ListOfAllPropertyUseTypes"].str.split(',').apply(lambda x: [tag.strip() for tag in x])
        self.mlb.fit(property_types)
        return self
    
    def transform(self, X):
        X_copy = X.copy()
        property_types = X_copy["ListOfAllPropertyUseTypes"].str.split(',').apply(lambda x: [tag.strip() for tag in x])
        tags_encoded = pd.DataFrame(
            self.mlb.transform(property_types),
            columns=self.mlb.classes_,
            index=X_copy.index
        )
        X_copy = X_copy.drop(["ListOfAllPropertyUseTypes"], axis=1)
        return pd.concat([X_copy, tags_encoded], axis=1)

class CategoricalEncoderTransformer(BaseEstimator, TransformerMixin):
    def __init__(self):
        self.encoders = {}
        self.all_feature_names = {}
        
    def fit(self, X, y=None):
        for column in X.select_dtypes(["object"]).columns:
            encoder = OneHotEncoder(handle_unknown='ignore')  # Ajout de handle_unknown='ignore'
            self.encoders[column] = encoder
            self.encoders[column].fit(X[column].values.reshape(-1, 1))
            # Stocker les noms des features pour chaque colonne
            self.all_feature_names[column] = self.encoders[column].get_feature_names_out([column])
        return self
    
    def transform(self, X):
        X_copy = X.copy()
        
        for column in self.encoders.keys():
            if column in X_copy.columns:
                # Transformation pour les colonnes présentes
                encoded = self.encoders[column].transform(X_copy[column].values.reshape(-1, 1)).toarray()
                feature_names = self.all_feature_names[column]
            else:
                # Création d'une matrice de zéros pour les colonnes manquantes
                encoded = np.zeros((len(X_copy), len(self.all_feature_names[column])))
                feature_names = self.all_feature_names[column]
            
            encoded_df = pd.DataFrame(encoded, columns=feature_names, index=X_copy.index)
            X_copy = pd.concat([X_copy, encoded_df], axis=1)
            
            # Ne supprimer la colonne que si elle existe
            if column in X_copy.columns:
                X_copy = X_copy.drop(column, axis=1)
        
        return X_copy.fillna(0)
# Création de la pipeline
preprocessing_pipeline = Pipeline([
    ('district_density', DistrictDensityTransformer()),
    ('feature_engineering', FeatureEngineeringTransformer()),
    ('type_conversion', TypeConversionTransformer()),
    ('property_type', PropertyTypeTransformer()),
    ('categorical_encoding', CategoricalEncoderTransformer())
])

# %%
# Exemple d'utilisation:
# Entraînement de la pipeline
# preprocessing_pipeline.fit(building_consumption)

# Sauvegarde de la pipeline
# joblib.dump(preprocessing_pipeline, 'preprocessing_pipeline.joblib')

# Chargement de la pipeline
# loaded_pipeline = joblib.load('preprocessing_pipeline.joblib')

# Application de la transformation
# transformed_data = loaded_pipeline.transform(new_data)

# %% [markdown]
# A réaliser :
#
# - Si ce n'est pas déjà fait, supprimer toutes les colonnes peu pertinentes pour la modélisation.
# - Tracer la distribution de la cible pour vous familiariser avec l'ordre de grandeur. En cas d'outliers, mettez en place une démarche pour les supprimer.
# - Débarrassez-vous des features redondantes en utilisant une matrice de corrélation.
# - Réalisez différents graphiques pour comprendre le lien entre vos features et la target (boxplots, scatterplots, pairplot si votre nombre de features numériques n'est pas très élevé).
# - Séparez votre jeu de données en un Pandas DataFrame X (ensemble de feautures) et Pandas Series y (votre target).
# - Si vous avez des features catégorielles, il faut les encoder pour que votre modèle fonctionne.

# %% [markdown]
# ### Préparation des features pour la modélisation

# %%
building_consumption.rename(columns={"SteamUse(kBtu)": "SteamUsekBtu", "NaturalGas(therms)": "NaturalGasTherms"}, inplace=True)

# %%
# Séparation de données en target
y = building_consumption["SiteEnergyUse(kBtu)"]
X = building_consumption.drop(columns=["SiteEnergyUse(kBtu)"])

# %%
# Séparation de données en train et test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=50)

# %%
# Standarisation des données
# scaler_x = StandardScaler()
# X_train_scaled = scaler_x.fit_transform(X_train)
# X_test_scaled = scaler_x.transform(X_test)

# scaler_y = StandardScaler()
# y_train_scaled = scaler_y.fit_transform(y_train.values.reshape(-1, 1)).ravel()
# y_test_scaled = scaler_y.transform(y_test.values.reshape(-1, 1)).ravel()

# %%
preprocessing_pipeline.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('district_density', DistrictDensityTransformer()),
#                 ('feature_engineering', FeatureEngineeringTransformer()),
#                 ('type_conversion', TypeConversionTransformer()),
#                 ('property_type', PropertyTypeTransformer()),
#                 ('categorical_encoding', CategoricalEncoderTransformer())])

# %%
joblib.dump(preprocessing_pipeline, "preprocessing.pipeline")
# Out:
# ['preprocessing.pipeline']

# %%
X_train_scaled = preprocessing_pipeline.transform(X_train)

# %%
X_test_scaled = preprocessing_pipeline.transform(X_test)
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/preprocessing/_label.py:900: UserWarning: unknown class(es) ['Police Station', 'Single Family Home'] will be ignored
#   warnings.warn(

# %%
scaler_y = StandardScaler()
y_train_scaled = scaler_y.fit_transform(y_train.values.reshape(-1, 1)).ravel()
y_test_scaled = scaler_y.transform(y_test.values.reshape(-1, 1)).ravel()

# %%
joblib.dump(scaler_y, "y.scaler")
# Out:
# ['y.scaler']

# %% [markdown]
# ### Comparaison de différents modèles supervisés

# %% [markdown]
# A réaliser :
#
# - Pour chaque algorithme que vous allez tester, vous devez :
#     - Réaliser au préalable une séparation en jeu d'apprentissage et jeu de test via une validation croisée.
#     - Si les features quantitatives que vous souhaitez utiliser ont des ordres de grandeur très différents les uns des autres, et que vous utilisez un algorithme de regression qui est sensible à cette différence, alors il faut réaliser un scaling (normalisation) de la donnée au préalable.
#     - Entrainer le modèle sur le jeu de Train
#     - Prédire la cible sur la donnée de test (nous appelons cette étape, l'inférence).
#     - Calculer les métriques de performance R2, MAE et RMSE sur le jeu de train et de test.
#     - Interpréter les résultats pour juger de la fiabilité de l'algorithme.
# - Vous pouvez choisir par exemple de tester un modèle linéaire, un modèle à base d'arbres et un modèle de type SVM
# - Déterminer le modèle le plus performant parmi ceux testés.

# %% [markdown]
# Dummy

# %%
# DummyRegressor
dummy = DummyRegressor(strategy='mean') 

# Entraînement avec les données d'entraînement
dummy.fit(X_train_scaled, y_train_scaled)

# Prediction sur les données de test
y_pred_dummy = dummy.predict(X_test_scaled)

# Calcul des scores
mse_dummy_test = mean_squared_error(y_pred_dummy, y_test_scaled)
mae_dummy_test = mean_absolute_error(y_pred_dummy, y_test_scaled)
rmse_dummy_test = root_mean_squared_error(y_pred_dummy, y_test_scaled)
r2_dummy_test = r2_score(y_pred_dummy, y_test_scaled)

dummy_test_score = {
    "Name": "Dummy",
    "Data": "Test",
    "GridSearch": False,
    "MSE": mse_dummy_test,
    "MAE": mae_dummy_test,
    "RMSE": rmse_dummy_test,
    "R2": r2_dummy_test
}
pprint(dummy_test_score)

scores = cross_val_score(dummy, X_train_scaled, y_train_scaled, cv=5)
print(f"Scores Cross validation: {scores}")
print(f"Moyenne: {scores.mean():.3f}")
# Out:
# {'Data': 'Test',
#  'GridSearch': False,
#  'MAE': 0.5359330973989517,
#  'MSE': 1.8544653909607443,
#  'Name': 'Dummy',
#  'R2': 0.0,
#  'RMSE': 1.3617875718924535}
# Scores Cross validation: [-7.96700118e-04 -3.59651253e-05 -2.39959972e-03 -3.67483246e-03
#  -1.14671992e-02]
# Moyenne: -0.004

# %%
# Prediction sur les données de test
y_train_pred_dummy = dummy.predict(X_train_scaled)

# Calcul des scores
mse_dummy_train = mean_squared_error(y_train_pred_dummy, y_train_scaled)
mae_dummy_train = mean_absolute_error(y_train_pred_dummy, y_train_scaled)
rmse_dummy_train = root_mean_squared_error(y_train_pred_dummy, y_train_scaled)
r2_dummy_train = r2_score(y_train_pred_dummy, y_train_scaled)

dummy_train_score = {
    "Name": "Dummy",
    "Data": "Train",
    "GridSearch": False,
    "MSE": mse_dummy_train,
    "MAE": mae_dummy_train,
    "RMSE": rmse_dummy_train,
    "R2": r2_dummy_train
}
pprint(dummy_train_score)
# Out:
# {'Data': 'Train',
#  'GridSearch': False,
#  'MAE': 0.521509740011003,
#  'MSE': 1.0,
#  'Name': 'Dummy',
#  'R2': 0.0,
#  'RMSE': 1.0}

# %% [markdown]
# Linear Regression

# %%
# LinearRegression
liner_regression = LinearRegression() 

# Entraînement avec les données d'entraînement
liner_regression.fit(X_train_scaled, y_train_scaled)

# Prediction sur les données de test
y_test_pred_linear_regression = liner_regression.predict(X_test_scaled)

# Calcul des scores
mse_linear_regression_test = mean_squared_error(y_test_pred_linear_regression, y_test_scaled)
mae_linear_regression_test = mean_absolute_error(y_test_pred_linear_regression, y_test_scaled)
rmse_linear_regression_test = root_mean_squared_error(y_test_pred_linear_regression, y_test_scaled)
r2_linear_regression_test = r2_score(y_test_pred_linear_regression, y_test_scaled)

linear_regression_test_pred_score = {
    "Name": "Linear Regression",
    "Data": "Test",
    "GridSearch": False,
    "MSE": mse_linear_regression_test,
    "MAE": mae_linear_regression_test,
    "RMSE": rmse_linear_regression_test,
    "R2": r2_linear_regression_test
}
pprint(linear_regression_test_pred_score)

scores = cross_val_score(liner_regression, X_train_scaled, y_train_scaled, cv=5)
print(f"Scores Cross validation: {scores}")
print(f"Moyenne: {scores.mean():.3f}")
# Out:
# {'Data': 'Test',
#  'GridSearch': False,
#  'MAE': 21.58220565700804,
#  'MSE': 13381.037438831783,
#  'Name': 'Linear Regression',
#  'R2': -0.005509060836766055,
#  'RMSE': 115.67643424151603}
# Scores Cross validation: [-7.28336061e+08 -1.74771000e+05 -4.90887395e+03 -1.81393747e+08
#  -2.36974263e+05]
# Moyenne: -182029292.491

# %%
# Prediction sur les données de test
y_train_pred_linear_regression = liner_regression.predict(X_train_scaled)

# Calcul des scores
mse_linear_regression_train = mean_squared_error(y_train_pred_linear_regression, y_train_scaled)
mae_linear_regression_train = mean_absolute_error(y_train_pred_linear_regression, y_train_scaled)
rmse_linear_regression_train = root_mean_squared_error(y_train_pred_linear_regression, y_train_scaled)
r2_linear_regression_train = r2_score(y_train_pred_linear_regression, y_train_scaled)

linear_regression_train_pred_score = {
    "Name": "Linear Regression",
    "Data": "Train",
    "GridSearch": False,
    "MSE": mse_linear_regression_train,
    "MAE": mae_linear_regression_train,
    "RMSE": rmse_linear_regression_train,
    "R2": r2_linear_regression_train
}
pprint(linear_regression_train_pred_score)
# Out:
# {'Data': 'Train',
#  'GridSearch': False,
#  'MAE': 0.13362756565717968,
#  'MSE': 0.05889357030193161,
#  'Name': 'Linear Regression',
#  'R2': 0.9374214622333941,
#  'RMSE': 0.24267997507402955}

# %% [markdown]
# SVR

# %%
# SVR
svr = SVR() 

# Entraînement avec les données d'entraînement
svr.fit(X_train_scaled, y_train_scaled)

# Prediction sur les données de test
y_pred_test_svr = svr.predict(X_test_scaled)

# Calcul des scores
mse_test_svr = mean_squared_error(y_pred_test_svr, y_test_scaled)
mae_test_svr = mean_absolute_error(y_pred_test_svr, y_test_scaled)
rmse_test_svr = root_mean_squared_error(y_pred_test_svr, y_test_scaled)
r2_test_svr = r2_score(y_pred_test_svr, y_test_scaled)

svr_test_score_pred = {
    "Name": "SVR",
    "Data": "Test",
    "GridSearch": False,
    "MSE": mse_test_svr,
    "MAE": mae_test_svr,
    "RMSE": rmse_test_svr,
    "R2": r2_test_svr
}
pprint(svr_test_score_pred)


scores = cross_val_score(svr, X_train_scaled, y_train_scaled, cv=5)
print(f"Scores Cross validation: {scores}")
print(f"Moyenne: {scores.mean():.3f}")
# Out:
# {'Data': 'Test',
#  'GridSearch': False,
#  'MAE': 0.2490164553649288,
#  'MSE': 1.283704260359526,
#  'Name': 'SVR',
#  'R2': -4.493609658413304,
#  'RMSE': 1.1330067344722738}
# Scores Cross validation: [0.69223634 0.56147791 0.60892102 0.52367189 0.86736424]
# Moyenne: 0.651

# %%
# Prediction sur les données de test
y_pred_train_svr = svr.predict(X_train_scaled)

# Calcul des scores
mse_train_svr = mean_squared_error(y_pred_train_svr, y_train_scaled)
mae_train_svr = mean_absolute_error(y_pred_train_svr, y_train_scaled)
rmse_train_svr = root_mean_squared_error(y_pred_train_svr, y_train_scaled)
r2_train_svr = r2_score(y_pred_train_svr, y_train_scaled)

svr_train_score_pred = {
    "Name": "SVR",
    "Data": "Train",
    "GridSearch": False,
    "MSE": mse_train_svr,
    "MAE": mae_train_svr,
    "RMSE": rmse_train_svr,
    "R2": r2_train_svr
}
pprint(svr_train_score_pred)
# Out:
# {'Data': 'Train',
#  'GridSearch': False,
#  'MAE': 0.21144646937261088,
#  'MSE': 0.33104050432338106,
#  'Name': 'SVR',
#  'R2': 0.17314163033203067,
#  'RMSE': 0.5753611946624321}

# %% [markdown]
# Random Forest

# %%
# RandomForestRegressor
random_forest = RandomForestRegressor() 

# Entraînement avec les données d'entraînement
random_forest.fit(X_train_scaled, y_train_scaled)

# Prediction sur les données de test
y_test_pred_random_forest = random_forest.predict(X_test_scaled)

# Calcul des scores
mse_test_random_forest = mean_squared_error(y_test_pred_random_forest, y_test_scaled)
mae_test_random_forest = mean_absolute_error(y_test_pred_random_forest, y_test_scaled)
rmse_test_random_forest = root_mean_squared_error(y_test_pred_random_forest, y_test_scaled)
r2_test_random_forest = r2_score(y_test_pred_random_forest, y_test_scaled)

random_forest_test_score_pred = {
    "Name": "Random Forest",
    "Data": "Tets",
    "GridSearch": False,
    "MSE": mse_test_random_forest,
    "MAE": mae_test_random_forest,
    "RMSE": rmse_test_random_forest,
    "R2": r2_test_random_forest
}
pprint(random_forest_test_score_pred)

scores = cross_val_score(random_forest, X_train_scaled, y_train_scaled, cv=5)
print(f"Scores: {scores}")
print(f"Moyenne: {scores.mean():.3f}")
# Out:
# {'Data': 'Tets',
#  'GridSearch': False,
#  'MAE': 0.19980369758629513,
#  'MSE': 1.174365718917516,
#  'Name': 'Random Forest',
#  'R2': -1.8079589423251567,
#  'RMSE': 1.0836815578930539}
# Scores: [0.75269886 0.66005391 0.72590242 0.62496435 0.81538009]
# Moyenne: 0.716

# %%
# Prediction sur les données de test
y_train_pred_random_forest = random_forest.predict(X_train_scaled)

# Calcul des scores
mse_train_random_forest = mean_squared_error(y_train_pred_random_forest, y_train_scaled)
mae_train_random_forest = mean_absolute_error(y_train_pred_random_forest, y_train_scaled)
rmse_train_random_forest = root_mean_squared_error(y_train_pred_random_forest, y_train_scaled)
r2_train_random_forest = r2_score(y_train_pred_random_forest, y_train_scaled)

random_forest_train_score_pred = {
    "Name": "Random Forest",
    "Data": "Train",
    "GridSearch": False,
    "MSE": mse_train_random_forest,
    "MAE": mae_train_random_forest,
    "RMSE": rmse_train_random_forest,
    "R2": r2_train_random_forest
}
pprint(random_forest_train_score_pred)
# Out:
# {'Data': 'Train',
#  'GridSearch': False,
#  'MAE': 0.06921444047075073,
#  'MSE': 0.04562137956442233,
#  'Name': 'Random Forest',
#  'R2': 0.9392312805470581,
#  'RMSE': 0.21359161866614132}

# %% [markdown]
# Linear Regression avec régulateur Lasso

# %%
# LinearRegrssion avec régularisation Lasso
lasso = linear_model.Lasso(alpha=0.1)
lasso.fit(X_train_scaled, y_train_scaled)

y_pred_test_lasso = lasso.predict(X_test_scaled)

# Calcul des scores
mse_test_lasso = mean_squared_error(y_pred_test_lasso, y_test_scaled)
mae_test_lasso = mean_absolute_error(y_pred_test_lasso, y_test_scaled)
rmse_test_lasso = root_mean_squared_error(y_pred_test_lasso, y_test_scaled)
r2_test_lasso = r2_score(y_pred_test_lasso, y_test_scaled)


# Calcul des scores
lasso_test_score_pred = {
    "Name": "Lasso",
    "Data": "Test",
    "GridSearch": False,
    "MSE": mse_test_lasso,
    "MAE": mae_test_lasso,
    "RMSE": rmse_test_lasso,
    "R2": r2_test_lasso
}

pprint(lasso_test_score_pred)

scores = cross_val_score(lasso, X_train_scaled, y_train_scaled, cv=5)
print(f"Scores: {scores}")
print(f"Moyenne: {scores.mean():.3f}")
# Out:
# {'Data': 'Test',
#  'GridSearch': False,
#  'MAE': 0.20846517817960003,
#  'MSE': 1.18347860749704,
#  'Name': 'Lasso',
#  'R2': -1.3926033042271784,
#  'RMSE': 1.0878780296968222}
# Scores: [0.70849492 0.94125168 0.81066767 0.67900578 0.86574624]
# Moyenne: 0.801

# %%
y_pred_train_lasso = lasso.predict(X_train_scaled)

# Calcul des scores
mse_train_lasso = mean_squared_error(y_pred_train_lasso, y_train_scaled)
mae_train_lasso = mean_absolute_error(y_pred_train_lasso, y_train_scaled)
rmse_train_lasso = root_mean_squared_error(y_pred_train_lasso, y_train_scaled)
r2_train_lasso = r2_score(y_pred_train_lasso, y_train_scaled)


# Calcul des scores
lasso_train_score_pred = {
    "Name": "Lasso",
    "Data": "Train",
    "GridSearch": False,
    "MSE": mse_train_lasso,
    "MAE": mae_train_lasso,
    "RMSE": rmse_train_lasso,
    "R2": r2_train_lasso
}

pprint(lasso_train_score_pred)
# Out:
# {'Data': 'Train',
#  'GridSearch': False,
#  'MAE': 0.17274861500872302,
#  'MSE': 0.1527321392126205,
#  'Name': 'Lasso',
#  'R2': 0.8192144349600188,
#  'RMSE': 0.39080959457595266}

# %% [markdown]
# Linear Regression avec régulateur Ridge

# %%
# LinearRegrssion avec régularisation Ridge
ridge = linear_model.Ridge(alpha=0.1)
ridge.fit(X_train_scaled, y_train_scaled)

y_pred_test_ridge = ridge.predict(X_test_scaled)

# Calcul des scores
mse_test_ridge = mean_squared_error(y_pred_test_ridge, y_test_scaled)
mae_test_ridge = mean_absolute_error(y_pred_test_ridge, y_test_scaled)
rmse_test_ridge = root_mean_squared_error(y_pred_test_ridge, y_test_scaled)
r2_test_ridge = r2_score(y_pred_test_ridge, y_test_scaled)


# Calcul des scores
ridge_test_score_pred = {
    "Name": "Ridge",
    "Data": "Test",
    "GridSearch": False,
    "MSE": mse_test_ridge,
    "MAE": mae_test_ridge,
    "RMSE": rmse_test_ridge,
    "R2": r2_test_ridge
}

pprint(ridge_test_score_pred)

scores = cross_val_score(ridge, X_train_scaled, y_train_scaled, cv=5)
print(f"Scores: {scores}")
print(f"Moyenne: {scores.mean():.3f}")
# Out:
# {'Data': 'Test',
#  'GridSearch': False,
#  'MAE': 0.2683426481649282,
#  'MSE': 0.9635491145243301,
#  'Name': 'Ridge',
#  'R2': -0.5783779927803152,
#  'RMSE': 0.9816053761692273}
# Scores: [0.67932599 0.9092029  0.71763192 0.69494651 0.72522579]
# Moyenne: 0.745
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=7.39927e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=8.50186e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=1.0011e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=7.66254e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=1.38201e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=8.75777e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T

# %%
y_pred_train_ridge = ridge.predict(X_train_scaled)

# Calcul des scores
mse_train_ridge = mean_squared_error(y_pred_train_ridge, y_train_scaled)
mae_train_ridge = mean_absolute_error(y_pred_train_ridge, y_train_scaled)
rmse_train_ridge = root_mean_squared_error(y_pred_train_ridge, y_train_scaled)
r2_train_ridge = r2_score(y_pred_train_ridge, y_train_scaled)


# Calcul des scores
ridge_train_score_pred = {
    "Name": "Ridge",
    "Data": "Train",
    "GridSearch": False,
    "MSE": mse_train_ridge,
    "MAE": mae_train_ridge,
    "RMSE": rmse_train_ridge,
    "R2": r2_train_ridge
}

pprint(ridge_train_score_pred)
# Out:
# {'Data': 'Train',
#  'GridSearch': False,
#  'MAE': 0.13767839964850218,
#  'MSE': 0.06066725456170689,
#  'Name': 'Ridge',
#  'R2': 0.9347845716487948,
#  'RMSE': 0.24630723611316596}

# %% [markdown]
# Xgboost

# %%
# XGBOOST
xgboost = XGBRegressor()

# Entraînement avec les données d'entraînement
xgboost.fit(X_train_scaled, y_train_scaled)

# Prediction sur les données de test
y_pred_test_xgboost = xgboost.predict(X_test_scaled)

mse_test_xgboost = mean_squared_error(y_pred_test_xgboost, y_test_scaled)
mae_test_xgboost = mean_absolute_error(y_pred_test_xgboost, y_test_scaled)
rmse_test_xgboost = root_mean_squared_error(y_pred_test_xgboost, y_test_scaled)
r2_test_xgboost = r2_score(y_pred_test_xgboost, y_test_scaled)


# Calcul des scores
xgboost_test_score_pred = {
    "Name": "Xgboost",
    "Data": "Test",
    "GridSearch": False,
    "MSE": mse_test_xgboost,
    "MAE": mae_test_xgboost,
    "RMSE": rmse_test_xgboost,
    "R2": r2_test_xgboost
}

pprint(xgboost_test_score_pred)

scores = cross_val_score(xgboost, X_train_scaled, y_train_scaled, cv=5)
print(f"Scores: {scores}")
print(f"Moyenne: {scores.mean():.3f}")
# Out:
# {'Data': 'Test',
#  'GridSearch': False,
#  'MAE': 0.2230350197565943,
#  'MSE': 1.1726545459797304,
#  'Name': 'Xgboost',
#  'R2': -0.879066895801748,
#  'RMSE': 1.0828917517368624}
# Scores: [0.67991081 0.68149679 0.75234053 0.61198649 0.79697738]
# Moyenne: 0.705

# %%
y_pred_train_xgboost = xgboost.predict(X_train_scaled)

# Calcul des scores
mse_train_xgboost = mean_squared_error(y_pred_train_xgboost, y_train_scaled)
mae_train_xgboost = mean_absolute_error(y_pred_train_xgboost, y_train_scaled)
rmse_train_xgboost = root_mean_squared_error(y_pred_train_xgboost, y_train_scaled)
r2_train_xgboost = r2_score(y_pred_train_xgboost, y_train_scaled)


# Calcul des scores
xgboost_train_score_pred = {
    "Name": "Xgboost",
    "Data": "Train",
    "GridSearch": False,
    "MSE": mse_train_xgboost,
    "MAE": mae_train_xgboost,
    "RMSE": rmse_train_xgboost,
    "R2": r2_train_xgboost
}

pprint(xgboost_train_score_pred)
# Out:
# {'Data': 'Train',
#  'GridSearch': False,
#  'MAE': 0.02981063927997694,
#  'MSE': 0.0019095404997483655,
#  'Name': 'Xgboost',
#  'R2': 0.9980650127041023,
#  'RMSE': 0.04369828943732655}

# %% [markdown]
# ### Optimisation et interprétation du modèle

# %% [markdown]
# A réaliser :
#
# - Reprennez le meilleur algorithme que vous avez sécurisé via l'étape précédente, et réalisez une GridSearch de petite taille sur au moins 3 hyperparamètres.
# - Si le meilleur modèle fait partie de la famille des modèles à arbres (RandomForest, GradientBoosting) alors utilisez la fonctionnalité feature importance pour identifier les features les plus impactantes sur la performance du modèle. Sinon, utilisez la méthode Permutation Importance de sklearn.

# %% [markdown]
# ### GridSearchCV

# %% [markdown]
# Linear Regression

# %%
# LinearRegression
params = {
   'fit_intercept': [True, False],
   'copy_X': [True, False],
   'positive': [True, False],
   'n_jobs': [None, -1]
}

linear_grid = GridSearchCV(LinearRegression(), params, cv=5)
linear_grid.fit(X_train_scaled, y_train_scaled)
print(f"Best params: {linear_grid.best_params_}")

# Tous les scores
scores_df = pd.DataFrame(linear_grid.cv_results_)

y_pred_test_gd_linear_regression = linear_grid.predict(X_test_scaled)

mse_test_gd_linear_regression = mean_squared_error(y_pred_test_gd_linear_regression, y_test_scaled)
mae_test_gd_linear_regression = mean_absolute_error(y_pred_test_gd_linear_regression, y_test_scaled)
rmse_test_gd_linear_regression = root_mean_squared_error(y_pred_test_gd_linear_regression, y_test_scaled)
r2_test_gd_linear_regression = r2_score(y_pred_test_gd_linear_regression, y_test_scaled)


# Calcul des scores
linear_regression_test_gd_score_pred = {
    "Name": "Linear Regression",
    "Data": "Test",
    "GridSearch": True,
    "MSE": mse_test_gd_linear_regression,
    "MAE": mae_test_gd_linear_regression,
    "RMSE": rmse_test_gd_linear_regression,
    "R2": r2_test_gd_linear_regression
}

pprint(linear_regression_test_gd_score_pred)
# Out:
# Best params: {'copy_X': True, 'fit_intercept': False, 'n_jobs': None, 'positive': True}
# {'Data': 'Test',
#  'GridSearch': True,
#  'MAE': 0.5193002179910343,
#  'MSE': 1.1983838719917137,
#  'Name': 'Linear Regression',
#  'R2': -2.290289724089366,
#  'RMSE': 1.094707208340072}

# %%
y_pred_train_gd_linear_regression = linear_grid.predict(X_train_scaled)

mse_train_gd_linear_regression = mean_squared_error(y_pred_train_gd_linear_regression, y_train_scaled)
mae_train_gd_linear_regression = mean_absolute_error(y_pred_train_gd_linear_regression, y_train_scaled)
rmse_train_gd_linear_regression = root_mean_squared_error(y_pred_train_gd_linear_regression, y_train_scaled)
r2_train_gd_linear_regression = r2_score(y_pred_train_gd_linear_regression, y_train_scaled)


# Calcul des scores
linear_regression_train_gd_score_pred = {
    "Name": "Linear Regression",
    "Data": "Train",
    "GridSearch": True,
    "MSE": mse_train_gd_linear_regression,
    "MAE": mae_train_gd_linear_regression,
    "RMSE": rmse_train_gd_linear_regression,
    "R2": r2_train_gd_linear_regression
}

pprint(linear_regression_train_gd_score_pred)
# Out:
# {'Data': 'Train',
#  'GridSearch': True,
#  'MAE': 0.47066437330431815,
#  'MSE': 0.29948077643606935,
#  'Name': 'Linear Regression',
#  'R2': 0.473038711774582,
#  'RMSE': 0.5472483681438158}

# %%
linear_best_model = linear_grid.best_estimator_

results = permutation_importance(linear_best_model, X_train_scaled, y_train_scaled, scoring='neg_mean_squared_error')

# get importance
importance = results.importances_mean

# summarize feature importance
for i,v in enumerate(importance):
    print('Feature: %s, Score: %.5f' % (X_train_scaled.columns.values[i],v))
# plot feature importance
plt.bar([x for x in range(len(importance))], importance)
plt.show()
# Out:
# Feature: NumberofBuildings, Score: 0.00000
# Feature: NumberofFloors, Score: 0.00000
# Feature: PropertyGFATotal, Score: 0.19125
# Feature: PropertyGFAParking, Score: 0.01080
# Feature: SteamUsekBtu, Score: 0.09563
# Feature: NaturalGasTherms, Score: 0.64382
# Feature: DefaultData, Score: 0.00000
# Feature: DistrictDensity, Score: 0.00000
# Feature: BuildingAge, Score: 0.00000
# Feature: MeanFloorGFA, Score: 0.00000
# Feature: RationParking, Score: 0.00000
# Feature: Adult Education, Score: 0.00000
# Feature: Automobile Dealership, Score: 0.00000
# Feature: Bank Branch, Score: 0.00000
# Feature: Bar/Nightclub, Score: 0.00000
# Feature: College/University, Score: 0.00000
# Feature: Convenience Store without Gas Station, Score: 0.00072
# Feature: Convention Center, Score: 0.00000
# Feature: Courthouse, Score: 0.00000
# Feature: Data Center, Score: 0.00154
# Feature: Distribution Center, Score: 0.00000
# Feature: Dry Cleaning, Score: 0.00000
# Feature: Enclosed Mall, Score: 0.00000
# Feature: Fast Food Restaurant, Score: 0.00000
# Feature: Financial Office, Score: 0.01234
# Feature: Fire Station, Score: 0.00000
# Feature: Fitness Center/Health Club/Gym, Score: 0.00000
# Feature: Food Sales, Score: 0.00000
# Feature: Food Service, Score: 0.00000
# Feature: Hospital (General Medical & Surgical), Score: 0.00383
# Feature: Hotel, Score: 0.00000
# Feature: K-12 School, Score: 0.00000
# Feature: Laboratory, Score: 0.00162
# Feature: Library, Score: 0.00000
# Feature: Lifestyle Center, Score: 0.00000
# Feature: Locksmith, Score: 0.00000
# Feature: Manufacturing/Industrial Plant, Score: 0.00000
# Feature: Medical Office, Score: 0.00000
# Feature: Movie Theater, Score: 0.00000
# Feature: Multifamily Housing, Score: 0.00000
# Feature: Museum, Score: 0.00000
# Feature: Non-Refrigerated Warehouse, Score: 0.00000
# Feature: Office, Score: 0.00000
# Feature: Other, Score: 0.00000
# Feature: Other - Education, Score: 0.00000
# Feature: Other - Entertainment/Public Assembly, Score: 0.00000
# Feature: Other - Lodging/Residential, Score: 0.00000
# Feature: Other - Mall, Score: 0.00000
# Feature: Other - Public Services, Score: 0.00000
# Feature: Other - Recreation, Score: 0.00000
# Feature: Other - Restaurant/Bar, Score: 0.00000
# Feature: Other - Services, Score: 0.00000
# Feature: Other - Technology/Science, Score: 0.00000
# Feature: Other - Utility, Score: 0.00000
# Feature: Other/Specialty Hospital, Score: 0.00000
# Feature: YearBuilt_1973, Score: 0.00000
# Feature: YearBuilt_1974, Score: 0.00000
# Feature: YearBuilt_1975, Score: 0.00000
# Feature: YearBuilt_1976, Score: 0.00000
# Feature: YearBuilt_1977, Score: 0.00000
# Feature: YearBuilt_1978, Score: 0.00000
# Feature: YearBuilt_1979, Score: 0.00000
# Feature: YearBuilt_1980, Score: 0.00000
# Feature: YearBuilt_1981, Score: 0.00000
# Feature: YearBuilt_1982, Score: 0.00000
# Feature: YearBuilt_1983, Score: 0.00000
# Feature: YearBuilt_1984, Score: 0.00000
# Feature: YearBuilt_1985, Score: 0.00000
# Feature: YearBuilt_1986, Score: 0.00000
# Feature: YearBuilt_1987, Score: 0.00000
# Feature: YearBuilt_1988, Score: 0.00000
# Feature: YearBuilt_1989, Score: 0.00000
# Feature: YearBuilt_1990, Score: 0.00000
# Feature: YearBuilt_1991, Score: 0.00000
# Feature: YearBuilt_1992, Score: 0.00000
# Feature: YearBuilt_1993, Score: 0.00000
# Feature: YearBuilt_1994, Score: 0.00000
# Feature: YearBuilt_1995, Score: 0.00000
# Feature: YearBuilt_1996, Score: 0.00000
# Feature: YearBuilt_1997, Score: 0.00000
# Feature: YearBuilt_1998, Score: 0.00000
# Feature: YearBuilt_1999, Score: 0.00012
# Feature: YearBuilt_2000, Score: 0.00000
# Feature: YearBuilt_2001, Score: 0.00000
# Feature: YearBuilt_2002, Score: 0.00000
# Feature: YearBuilt_2003, Score: 0.00000
# Feature: YearBuilt_2004, Score: 0.00000
# Feature: YearBuilt_2005, Score: 0.00000
# Feature: YearBuilt_2006, Score: 0.00000
# Feature: YearBuilt_2007, Score: 0.00000
# Feature: YearBuilt_2008, Score: 0.00000
# Feature: YearBuilt_2009, Score: 0.00000
# Feature: YearBuilt_2010, Score: 0.00000
# Feature: YearBuilt_2011, Score: 0.00000
# Feature: YearBuilt_2012, Score: 0.00000
# Feature: YearBuilt_2013, Score: 0.00000
# Feature: YearBuilt_2014, Score: 0.00000
# Feature: YearBuilt_2015, Score: 0.00000
# Feature: LargestPropertyUseType_Adult Education, Score: 0.00000
# Feature: LargestPropertyUseType_Automobile Dealership, Score: 0.00000
# Feature: LargestPropertyUseType_Bank Branch, Score: 0.00000
# Feature: LargestPropertyUseType_College/University, Score: 0.00000
# Feature: LargestPropertyUseType_Convention Center, Score: 0.00000
# Feature: LargestPropertyUseType_Courthouse, Score: 0.00011
# Feature: LargestPropertyUseType_Data Center, Score: 0.01504
# Feature: LargestPropertyUseType_Distribution Center, Score: 0.00000
# Feature: LargestPropertyUseType_Financial Office, Score: 0.00000
# Feature: LargestPropertyUseType_Fire Station, Score: 0.00000
# Feature: LargestPropertyUseType_Fitness Center/Health Club/Gym, Score: 0.00000
# Feature: LargestPropertyUseType_Food Service, Score: 0.00000
# Feature: LargestPropertyUseType_Hospital (General Medical & Surgical), Score: 0.00000
# Feature: LargestPropertyUseType_Hotel, Score: 0.00000
# Feature: LargestPropertyUseType_K-12 School, Score: 0.00000
# Feature: LargestPropertyUseType_Laboratory, Score: 0.00000
# Feature: LargestPropertyUseType_Library, Score: 0.00000
# Feature: LargestPropertyUseType_Lifestyle Center, Score: 0.00000
# Feature: LargestPropertyUseType_Manufacturing/Industrial Plant, Score: 0.00000
# Feature: LargestPropertyUseType_Medical Office, Score: 0.00000
# Feature: LargestPropertyUseType_Movie Theater, Score: 0.00000
# Feature: LargestPropertyUseType_Multifamily Housing, Score: 0.00000
# Feature: LargestPropertyUseType_Museum, Score: 0.00000
# Feature: LargestPropertyUseType_Non-Refrigerated Warehouse, Score: 0.00000
# Feature: LargestPropertyUseType_Office, Score: 0.00000
# Feature: LargestPropertyUseType_Other, Score: 0.00000
# Feature: LargestPropertyUseType_Other - Education, Score: 0.00000
# Feature: LargestPropertyUseType_Other - Entertainment/Public Assembly, Score: 0.00000
# Feature: LargestPropertyUseType_Other - Lodging/Residential, Score: 0.00000
# Feature: LargestPropertyUseType_Other - Mall, Score: 0.00028
# Feature: LargestPropertyUseType_Other - Public Services, Score: 0.00000
# Feature: LargestPropertyUseType_Other - Recreation, Score: 0.00000
# Feature: LargestPropertyUseType_Other - Services, Score: 0.00000
# Feature: LargestPropertyUseType_Other - Utility, Score: 0.00000
# Feature: LargestPropertyUseType_Other/Specialty Hospital, Score: 0.00000
# Feature: LargestPropertyUseType_Parking, Score: 0.00000
# Feature: LargestPropertyUseType_Performing Arts, Score: 0.00000
# Feature: LargestPropertyUseType_Pre-school/Daycare, Score: 0.00000
# Feature: LargestPropertyUseType_Refrigerated Warehouse, Score: 0.00000
# Feature: LargestPropertyUseType_Repair Services (Vehicle, Shoe, Locksmith, etc), Score: 0.00000
# Feature: LargestPropertyUseType_Residence Hall/Dormitory, Score: 0.00000
# Feature: LargestPropertyUseType_Residential Care Facility, Score: 0.00000
# Feature: LargestPropertyUseType_Restaurant, Score: 0.00000
# Feature: LargestPropertyUseType_Retail Store, Score: 0.00000
# Feature: LargestPropertyUseType_Self-Storage Facility, Score: 0.00000
# Feature: LargestPropertyUseType_Senior Care Community, Score: 0.00000
# Feature: LargestPropertyUseType_Social/Meeting Hall, Score: 0.00000
# Feature: LargestPropertyUseType_Strip Mall, Score: 0.00000
# Feature: LargestPropertyUseType_Supermarket/Grocery Store, Score: 0.00000
# Feature: LargestPropertyUseType_Urgent Care/Clinic/Other Outpatient, Score: 0.00642
# Feature: LargestPropertyUseType_Wholesale Club/Supercenter, Score: 0.00000
# Feature: LargestPropertyUseType_Worship Facility, Score: 0.00000
# Feature: LargestPropertyUseType_nan, Score: 0.00000
# Feature: SecondLargestPropertyUseType_Automobile Dealership, Score: 0.00000
# Feature: SecondLargestPropertyUseType_Bank Branch, Score: 0.00000
# Feature: SecondLargestPropertyUseType_Bar/Nightclub, Score: 0.00000
# Feature: SecondLargestPropertyUseType_Courthouse, Score: 0.00000
# Feature: SecondLargestPropertyUseType_Data Center, Score: 0.00690
# Feature: SecondLargestPropertyUseType_Distribution Center, Score: 0.00000
# Feature: SecondLargestPropertyUseType_Enclosed Mall, Score: 0.00000
# Feature: SecondLargestPropertyUseType_Financial Office, Score: 0.00000
# Feature: SecondLargestPropertyUseType_Fitness Center/Health Club/Gym, Score: 0.00000
# Feature: SecondLargestPropertyUseType_Food Service, Score: 0.00000
# Feature: SecondLargestPropertyUseType_Hospital (General Medical & Surgical), Score: 0.00000
# Feature: SecondLargestPropertyUseType_Hotel, Score: 0.00000
# Feature: SecondLargestPropertyUseType_K-12 School, Score: 0.00000
# Feature: SecondLargestPropertyUseType_Laboratory, Score: 0.00028
# Feature: SecondLargestPropertyUseType_Manufacturing/Industrial Plant, Score: 0.00000
# Feature: SecondLargestPropertyUseType_Medical Office, Score: 0.00000
# Feature: SecondLargestPropertyUseType_Movie Theater, Score: 0.00000
# Feature: SecondLargestPropertyUseType_Multifamily Housing, Score: 0.00000
# Feature: SecondLargestPropertyUseType_Non-Refrigerated Warehouse, Score: 0.00000
# Feature: SecondLargestPropertyUseType_Office, Score: 0.00000
# Feature: SecondLargestPropertyUseType_Other, Score: 0.00000
# Feature: SecondLargestPropertyUseType_Other - Education, Score: 0.00000
# Feature: SecondLargestPropertyUseType_Other - Entertainment/Public Assembly, Score: 0.00000
# Feature: SecondLargestPropertyUseType_Other - Lodging/Residential, Score: 0.00000
# Feature: SecondLargestPropertyUseType_Other - Public Services, Score: 0.00000
# Feature: SecondLargestPropertyUseType_Other - Recreation, Score: 0.00039
# Feature: SecondLargestPropertyUseType_Other - Restaurant/Bar, Score: 0.00000
# Feature: SecondLargestPropertyUseType_Other - Services, Score: 0.00000
# Feature: SecondLargestPropertyUseType_Parking, Score: 0.00000
# Feature: SecondLargestPropertyUseType_Performing Arts, Score: 0.00000
# Feature: SecondLargestPropertyUseType_Personal Services (Health/Beauty, Dry Cleaning, etc), Score: 0.00000
# Feature: SecondLargestPropertyUseType_Pre-school/Daycare, Score: 0.00000
# Feature: SecondLargestPropertyUseType_Refrigerated Warehouse, Score: 0.00272
# Feature: SecondLargestPropertyUseType_Repair Services (Vehicle, Shoe, Locksmith, etc), Score: 0.00000
# Feature: SecondLargestPropertyUseType_Residence Hall/Dormitory, Score: 0.00000
# Feature: SecondLargestPropertyUseType_Restaurant, Score: 0.00000
# Feature: SecondLargestPropertyUseType_Retail Store, Score: 0.00000
# Feature: SecondLargestPropertyUseType_Self-Storage Facility, Score: 0.00000
# Feature: SecondLargestPropertyUseType_Supermarket/Grocery Store, Score: 0.00000
# Feature: SecondLargestPropertyUseType_Swimming Pool, Score: 0.00000
# Feature: SecondLargestPropertyUseType_Vocational School, Score: 0.00000
# Feature: SecondLargestPropertyUseType_Worship Facility, Score: 0.00000
# Feature: SecondLargestPropertyUseType_nan, Score: 0.00000
# Feature: ThirdLargestPropertyUseType_Bank Branch, Score: 0.00000
# Feature: ThirdLargestPropertyUseType_Bar/Nightclub, Score: 0.00000
# Feature: ThirdLargestPropertyUseType_Convenience Store without Gas Station, Score: 0.00000
# Feature: ThirdLargestPropertyUseType_Data Center, Score: 0.00000
# Feature: ThirdLargestPropertyUseType_Distribution Center, Score: 0.00000
# Feature: ThirdLargestPropertyUseType_Fast Food Restaurant, Score: 0.00000
# Feature: ThirdLargestPropertyUseType_Financial Office, Score: 0.00000
# Feature: ThirdLargestPropertyUseType_Fitness Center/Health Club/Gym, Score: 0.00000
# Feature: ThirdLargestPropertyUseType_Food Service, Score: 0.00000
# Feature: ThirdLargestPropertyUseType_Hotel, Score: 0.00035
# Feature: ThirdLargestPropertyUseType_K-12 School, Score: 0.00000
# Feature: ThirdLargestPropertyUseType_Laboratory, Score: 0.00005
# Feature: ThirdLargestPropertyUseType_Medical Office, Score: 0.00000
# Feature: ThirdLargestPropertyUseType_Multifamily Housing, Score: 0.00000
# Feature: ThirdLargestPropertyUseType_Non-Refrigerated Warehouse, Score: 0.00000
# Feature: ThirdLargestPropertyUseType_Office, Score: 0.00000
# Feature: ThirdLargestPropertyUseType_Other, Score: 0.00834
# Feature: ThirdLargestPropertyUseType_Other - Education, Score: 0.00000
# Feature: ThirdLargestPropertyUseType_Other - Entertainment/Public Assembly, Score: 0.00000
# Feature: ThirdLargestPropertyUseType_Other - Recreation, Score: 0.00000
# Feature: ThirdLargestPropertyUseType_Other - Restaurant/Bar, Score: 0.00000
# Feature: ThirdLargestPropertyUseType_Other - Services, Score: 0.00000
# Feature: ThirdLargestPropertyUseType_Other - Technology/Science, Score: 0.00292
# Feature: ThirdLargestPropertyUseType_Parking, Score: 0.00000
# Feature: ThirdLargestPropertyUseType_Personal Services (Health/Beauty, Dry Cleaning, etc), Score: 0.00037
# Feature: ThirdLargestPropertyUseType_Pre-school/Daycare, Score: 0.00000
# Feature: ThirdLargestPropertyUseType_Refrigerated Warehouse, Score: 0.00000
# Feature: ThirdLargestPropertyUseType_Restaurant, Score: 0.00000
# Feature: ThirdLargestPropertyUseType_Retail Store, Score: 0.00000
# Feature: ThirdLargestPropertyUseType_Self-Storage Facility, Score: 0.00000
# Feature: ThirdLargestPropertyUseType_Social/Meeting Hall, Score: 0.00000
# Feature: ThirdLargestPropertyUseType_Supermarket/Grocery Store, Score: 0.00000
# Feature: ThirdLargestPropertyUseType_Swimming Pool, Score: 0.00000
# Feature: ThirdLargestPropertyUseType_Worship Facility, Score: 0.00000
# Feature: ThirdLargestPropertyUseType_nan, Score: 0.00000
# Feature: ComplianceStatus_Compliant, Score: 0.00000
# Feature: ComplianceStatus_Error - Correct Default Data, Score: 0.00000
# Feature: ComplianceStatus_Missing Data, Score: 0.00000
# Feature: ComplianceStatus_Non-Compliant, Score: 0.00000

# %% [markdown]
# Lasso

# %%
# Lasso
params = {
   'alpha': [0.001, 0.01, 0.1, 1, 10],
   'fit_intercept': [True, False],
   'max_iter': [1000, 2000],
   'selection': ['cyclic', 'random']
}

lasso_grid = GridSearchCV(lasso, params, cv=5)
lasso_grid.fit(X_train_scaled, y_train_scaled)
print(f"Best params: {lasso_grid.best_params_}")

# Tous les scores
scores_df = pd.DataFrame(lasso_grid.cv_results_)

y_pred_test_gd_lasso = lasso_grid.predict(X_test_scaled)

# Calcul des scores
mse_test_gd_lasso = mean_squared_error(y_pred_test_gd_lasso, y_test_scaled)
mae_test_gd_lasso = mean_absolute_error(y_pred_test_gd_lasso, y_test_scaled)
rmse_test_gd_lasso = root_mean_squared_error(y_pred_test_gd_lasso, y_test_scaled)
r2_test_gd_lasso = r2_score(y_pred_test_gd_lasso, y_test_scaled)


# Calcul des scores
lasso_test_gd_score_pred = {
    "Name": "Lasso",
    "Data": "Test",
    "GridSearch": True,
    "MSE": mse_test_gd_lasso,
    "MAE": mae_test_gd_lasso,
    "RMSE": rmse_test_gd_lasso,
    "R2": r2_test_gd_lasso
}

pprint(lasso_test_gd_score_pred)
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.350e+01, tolerance: 1.052e-01
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.778e+01, tolerance: 7.464e-02
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.243e+01, tolerance: 9.807e-02
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.499e+01, tolerance: 9.669e-02
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.146e+01, tolerance: 1.082e-01
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.349e+01, tolerance: 1.052e-01
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.781e+01, tolerance: 7.464e-02
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.248e+01, tolerance: 9.807e-02
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.499e+01, tolerance: 9.669e-02
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.145e+01, tolerance: 1.082e-01
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.245e+01, tolerance: 1.052e-01
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.777e+01, tolerance: 7.464e-02
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.241e+01, tolerance: 9.807e-02
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.097e+01, tolerance: 9.669e-02
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.069e+01, tolerance: 1.082e-01
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.316e+01, tolerance: 1.052e-01
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.780e+01, tolerance: 7.464e-02
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.234e+01, tolerance: 9.807e-02
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.494e+01, tolerance: 9.669e-02
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.104e+01, tolerance: 1.082e-01
#   model = cd_fast.enet_coordinate_descent(
# Best params: {'alpha': 1, 'fit_intercept': True, 'max_iter': 1000, 'selection': 'cyclic'}
# {'Data': 'Test',
#  'GridSearch': True,
#  'MAE': 0.20550793227269437,
#  'MSE': 1.2029280615474978,
#  'Name': 'Lasso',
#  'R2': -1.4757788011552404,
#  'RMSE': 1.096780771871707}

# %%
y_pred_train_gd_lasso = lasso_grid.predict(X_train_scaled)

mse_train_gd_lasso = mean_squared_error(y_pred_train_gd_lasso, y_train_scaled)
mae_train_gd_lasso = mean_absolute_error(y_pred_train_gd_lasso, y_train_scaled)
rmse_train_gd_lasso = root_mean_squared_error(y_pred_train_gd_lasso, y_train_scaled)
r2_train_gd_lasso = r2_score(y_pred_train_gd_lasso, y_train_scaled)


# Calcul des scores
lasso_train_gd_score_pred = {
    "Name": "Lasso",
    "Data": "Train",
    "GridSearch": True,
    "MSE": mse_train_gd_linear_regression,
    "MAE": mae_train_gd_linear_regression,
    "RMSE": rmse_train_gd_linear_regression,
    "R2": r2_train_gd_linear_regression
}

pprint(lasso_train_gd_score_pred)
# Out:
# {'Data': 'Train',
#  'GridSearch': True,
#  'MAE': 0.47066437330431815,
#  'MSE': 0.29948077643606935,
#  'Name': 'Lasso',
#  'R2': 0.473038711774582,
#  'RMSE': 0.5472483681438158}

# %%
lasso_best_model = lasso_grid.best_estimator_

results = permutation_importance(lasso_best_model, X_train_scaled, y_train_scaled, scoring='neg_mean_squared_error')

# get importance
importance = results.importances_mean

# summarize feature importance
for i,v in enumerate(importance):
    print('Feature: %s, Score: %.5f' % (X_train_scaled.columns.values[i],v))
# plot feature importance
plt.bar([x for x in range(len(importance))], importance)
plt.show()
# Out:
# Feature: NumberofBuildings, Score: 0.00000
# Feature: NumberofFloors, Score: 0.00000
# Feature: PropertyGFATotal, Score: 0.47151
# Feature: PropertyGFAParking, Score: 0.00001
# Feature: SteamUsekBtu, Score: 0.08578
# Feature: NaturalGasTherms, Score: 0.73821
# Feature: DefaultData, Score: 0.00000
# Feature: DistrictDensity, Score: 0.00068
# Feature: BuildingAge, Score: 0.00067
# Feature: MeanFloorGFA, Score: 0.00154
# Feature: RationParking, Score: 0.00000
# Feature: Adult Education, Score: 0.00000
# Feature: Automobile Dealership, Score: 0.00000
# Feature: Bank Branch, Score: 0.00000
# Feature: Bar/Nightclub, Score: 0.00000
# Feature: College/University, Score: 0.00000
# Feature: Convenience Store without Gas Station, Score: 0.00000
# Feature: YearBuilt_2002, Score: 0.00000
# Feature: YearBuilt_2003, Score: 0.00000
# Feature: YearBuilt_2004, Score: 0.00000
# Feature: YearBuilt_2005, Score: 0.00000
# Feature: YearBuilt_2006, Score: 0.00000
# Feature: YearBuilt_2007, Score: 0.00000
# Feature: YearBuilt_2008, Score: 0.00000
# Feature: YearBuilt_2009, Score: 0.00000
# Feature: YearBuilt_2010, Score: 0.00000
# Feature: YearBuilt_2011, Score: 0.00000
# Feature: YearBuilt_2012, Score: 0.00000
# Feature: YearBuilt_2013, Score: 0.00000
# Feature: YearBuilt_2014, Score: 0.00000
# Feature: YearBuilt_2015, Score: 0.00000
# Feature: LargestPropertyUseType_Adult Education, Score: 0.00000
# Feature: LargestPropertyUseType_Automobile Dealership, Score: 0.00000
# Feature: LargestPropertyUseType_Bank Branch, Score: 0.00000
# Feature: LargestPropertyUseType_College/University, Score: 0.00000
# Feature: LargestPropertyUseType_Convention Center, Score: 0.00000
# Feature: LargestPropertyUseType_Courthouse, Score: 0.00000
# Feature: LargestPropertyUseType_Data Center, Score: 0.00000
# Feature: LargestPropertyUseType_Distribution Center, Score: 0.00000
# Feature: LargestPropertyUseType_Financial Office, Score: 0.00000
# Feature: LargestPropertyUseType_Fire Station, Score: 0.00000
# Feature: LargestPropertyUseType_Fitness Center/Health Club/Gym, Score: 0.00000
# Feature: LargestPropertyUseType_Food Service, Score: 0.00000
# Feature: LargestPropertyUseType_Hospital (General Medical & Surgical), Score: 0.00000
# Feature: LargestPropertyUseType_Hotel, Score: 0.00000
# Feature: LargestPropertyUseType_K-12 School, Score: 0.00000
# Feature: LargestPropertyUseType_Laboratory, Score: 0.00000
# Feature: LargestPropertyUseType_Library, Score: 0.00000
# Feature: LargestPropertyUseType_Lifestyle Center, Score: 0.00000
# Feature: LargestPropertyUseType_Manufacturing/Industrial Plant, Score: 0.00000
# Feature: LargestPropertyUseType_Medical Office, Score: 0.00000
# Feature: LargestPropertyUseType_Movie Theater, Score: 0.00000
# Feature: LargestPropertyUseType_Multifamily Housing, Score: 0.00000
# Feature: LargestPropertyUseType_Museum, Score: 0.00000
# Feature: LargestPropertyUseType_Non-Refrigerated Warehouse, Score: 0.00000
# Feature: LargestPropertyUseType_Office, Score: 0.00000
# Feature: LargestPropertyUseType_Other, Score: 0.00000
# Feature: LargestPropertyUseType_Other - Education, Score: 0.00000
# Feature: LargestPropertyUseType_Other - Entertainment/Public Assembly, Score: 0.00000
# Feature: LargestPropertyUseType_Other - Lodging/Residential, Score: 0.00000
# Feature: LargestPropertyUseType_Other - Mall, Score: 0.00000
# Feature: LargestPropertyUseType_Other - Public Services, Score: 0.00000
# Feature: LargestPropertyUseType_Other - Recreation, Score: 0.00000
# Feature: LargestPropertyUseType_Other - Services, Score: 0.00000
# Feature: LargestPropertyUseType_Other - Utility, Score: 0.00000
# Feature: LargestPropertyUseType_Other/Specialty Hospital, Score: 0.00000
# Feature: LargestPropertyUseType_Parking, Score: 0.00000
# Feature: LargestPropertyUseType_Performing Arts, Score: 0.00000
# Feature: LargestPropertyUseType_Pre-school/Daycare, Score: 0.00000
# Feature: LargestPropertyUseType_Refrigerated Warehouse, Score: 0.00000
# Feature: LargestPropertyUseType_Repair Services (Vehicle, Shoe, Locksmith, etc), Score: 0.00000
# Feature: LargestPropertyUseType_Residence Hall/Dormitory, Score: 0.00000
# Feature: LargestPropertyUseType_Residential Care Facility, Score: 0.00000
# Feature: LargestPropertyUseType_Restaurant, Score: 0.00000
# Feature: LargestPropertyUseType_Retail Store, Score: 0.00000
# Feature: LargestPropertyUseType_Self-Storage Facility, Score: 0.00000
# Feature: LargestPropertyUseType_Senior Care Community, Score: 0.00000
# Feature: LargestPropertyUseType_Social/Meeting Hall, Score: 0.00000
# Feature: LargestPropertyUseType_Strip Mall, Score: 0.00000
# Feature: LargestPropertyUseType_Supermarket/Grocery Store, Score: 0.00000
# Feature: LargestPropertyUseType_Urgent Care/Clinic/Other Outpatient, Score: 0.00000
# Feature: LargestPropertyUseType_Wholesale Club/Supercenter, Score: 0.00000
# Feature: LargestPropertyUseType_Worship Facility, Score: 0.00000
# Feature: LargestPropertyUseType_nan, Score: 0.00000
# Feature: SecondLargestPropertyUseType_Automobile Dealership, Score: 0.00000
# Feature: SecondLargestPropertyUseType_Bank Branch, Score: 0.00000
# Feature: SecondLargestPropertyUseType_Bar/Nightclub, Score: 0.00000
# Feature: SecondLargestPropertyUseType_Courthouse, Score: 0.00000
# Feature: SecondLargestPropertyUseType_Data Center, Score: 0.00000
# Feature: SecondLargestPropertyUseType_Distribution Center, Score: 0.00000
# Feature: SecondLargestPropertyUseType_Enclosed Mall, Score: 0.00000
# Feature: SecondLargestPropertyUseType_Financial Office, Score: 0.00000
# Feature: SecondLargestPropertyUseType_Fitness Center/Health Club/Gym, Score: 0.00000
# Feature: SecondLargestPropertyUseType_Food Service, Score: 0.00000
# Feature: SecondLargestPropertyUseType_Hospital (General Medical & Surgical), Score: 0.00000
# Feature: SecondLargestPropertyUseType_Hotel, Score: 0.00000
# Feature: SecondLargestPropertyUseType_K-12 School, Score: 0.00000
# Feature: SecondLargestPropertyUseType_Laboratory, Score: 0.00000
# Feature: SecondLargestPropertyUseType_Manufacturing/Industrial Plant, Score: 0.00000
# Feature: SecondLargestPropertyUseType_Medical Office, Score: 0.00000
# Feature: SecondLargestPropertyUseType_Movie Theater, Score: 0.00000
# Feature: SecondLargestPropertyUseType_Multifamily Housing, Score: 0.00000
# Feature: SecondLargestPropertyUseType_Non-Refrigerated Warehouse, Score: 0.00000
# Feature: SecondLargestPropertyUseType_Office, Score: 0.00000
# Feature: SecondLargestPropertyUseType_Other, Score: 0.00000
# Feature: SecondLargestPropertyUseType_Other - Education, Score: 0.00000
# Feature: SecondLargestPropertyUseType_Other - Entertainment/Public Assembly, Score: 0.00000
# Feature: SecondLargestPropertyUseType_Other - Lodging/Residential, Score: 0.00000
# Feature: SecondLargestPropertyUseType_Other - Public Services, Score: 0.00000
# Feature: SecondLargestPropertyUseType_Other - Recreation, Score: 0.00000
# Feature: SecondLargestPropertyUseType_Other - Restaurant/Bar, Score: 0.00000
# Feature: SecondLargestPropertyUseType_Other - Services, Score: 0.00000
# Feature: SecondLargestPropertyUseType_Parking, Score: 0.00000
# Feature: SecondLargestPropertyUseType_Performing Arts, Score: 0.00000
# Feature: SecondLargestPropertyUseType_Personal Services (Health/Beauty, Dry Cleaning, etc), Score: 0.00000
# Feature: SecondLargestPropertyUseType_Pre-school/Daycare, Score: 0.00000
# Feature: SecondLargestPropertyUseType_Refrigerated Warehouse, Score: 0.00000
# Feature: SecondLargestPropertyUseType_Repair Services (Vehicle, Shoe, Locksmith, etc), Score: 0.00000
# Feature: SecondLargestPropertyUseType_Residence Hall/Dormitory, Score: 0.00000
# Feature: SecondLargestPropertyUseType_Restaurant, Score: 0.00000
# Feature: SecondLargestPropertyUseType_Retail Store, Score: 0.00000
# Feature: SecondLargestPropertyUseType_Self-Storage Facility, Score: 0.00000
# Feature: SecondLargestPropertyUseType_Supermarket/Grocery Store, Score: 0.00000
# Feature: SecondLargestPropertyUseType_Swimming Pool, Score: 0.00000
# Feature: SecondLargestPropertyUseType_Vocational School, Score: 0.00000
# Feature: SecondLargestPropertyUseType_Worship Facility, Score: 0.00000
# Feature: SecondLargestPropertyUseType_nan, Score: 0.00000
# Feature: ThirdLargestPropertyUseType_Bank Branch, Score: 0.00000
# Feature: ThirdLargestPropertyUseType_Bar/Nightclub, Score: 0.00000
# Feature: ThirdLargestPropertyUseType_Convenience Store without Gas Station, Score: 0.00000
# Feature: ThirdLargestPropertyUseType_Data Center, Score: 0.00000
# Feature: ThirdLargestPropertyUseType_Distribution Center, Score: 0.00000
# Feature: ThirdLargestPropertyUseType_Fast Food Restaurant, Score: 0.00000
# Feature: ThirdLargestPropertyUseType_Financial Office, Score: 0.00000
# Feature: ThirdLargestPropertyUseType_Fitness Center/Health Club/Gym, Score: 0.00000
# Feature: ThirdLargestPropertyUseType_Food Service, Score: 0.00000
# Feature: ThirdLargestPropertyUseType_Hotel, Score: 0.00000
# Feature: ThirdLargestPropertyUseType_K-12 School, Score: 0.00000
# Feature: ThirdLargestPropertyUseType_Laboratory, Score: 0.00000
# Feature: ThirdLargestPropertyUseType_Medical Office, Score: 0.00000
# Feature: ThirdLargestPropertyUseType_Multifamily Housing, Score: 0.00000
# Feature: ThirdLargestPropertyUseType_Non-Refrigerated Warehouse, Score: 0.00000
# Feature: ThirdLargestPropertyUseType_Office, Score: 0.00000
# Feature: ThirdLargestPropertyUseType_Other, Score: 0.00000
# Feature: ThirdLargestPropertyUseType_Other - Education, Score: 0.00000
# Feature: ThirdLargestPropertyUseType_Other - Entertainment/Public Assembly, Score: 0.00000
# Feature: ThirdLargestPropertyUseType_Other - Recreation, Score: 0.00000
# Feature: ThirdLargestPropertyUseType_Other - Restaurant/Bar, Score: 0.00000
# Feature: ThirdLargestPropertyUseType_Other - Services, Score: 0.00000
# Feature: ThirdLargestPropertyUseType_Other - Technology/Science, Score: 0.00000
# Feature: ThirdLargestPropertyUseType_Parking, Score: 0.00000
# Feature: ThirdLargestPropertyUseType_Personal Services (Health/Beauty, Dry Cleaning, etc), Score: 0.00000
# Feature: ThirdLargestPropertyUseType_Pre-school/Daycare, Score: 0.00000
# Feature: ThirdLargestPropertyUseType_Refrigerated Warehouse, Score: 0.00000
# Feature: ThirdLargestPropertyUseType_Restaurant, Score: 0.00000
# Feature: ThirdLargestPropertyUseType_Retail Store, Score: 0.00000
# Feature: ThirdLargestPropertyUseType_Self-Storage Facility, Score: 0.00000
# Feature: ThirdLargestPropertyUseType_Social/Meeting Hall, Score: 0.00000
# Feature: ThirdLargestPropertyUseType_Supermarket/Grocery Store, Score: 0.00000
# Feature: ThirdLargestPropertyUseType_Swimming Pool, Score: 0.00000
# Feature: ThirdLargestPropertyUseType_Worship Facility, Score: 0.00000
# Feature: ThirdLargestPropertyUseType_nan, Score: 0.00000
# Feature: ComplianceStatus_Compliant, Score: 0.00000
# Feature: ComplianceStatus_Error - Correct Default Data, Score: 0.00000
# Feature: ComplianceStatus_Missing Data, Score: 0.00000
# Feature: ComplianceStatus_Non-Compliant, Score: 0.00000

# %% [markdown]
# Ridge

# %%
# GridSearchCV sur Ridge
params = {
   'alpha': [0.001, 0.01, 0.1, 1, 10],
   'fit_intercept': [True, False],
   'max_iter': [500, 1000]
}

ridge_grid = GridSearchCV(ridge, params, cv=5)
ridge_grid.fit(X_train_scaled, y_train_scaled)
print(f"Best params: {ridge_grid.best_params_}")

# Tous les scores
scores_df = pd.DataFrame(ridge_grid.cv_results_)

y_pred_test_gd_ridge = ridge_grid.predict(X_test_scaled)

# Calcul des scores
mse_test_gd_ridge = mean_squared_error(y_pred_test_gd_ridge, y_test_scaled)
mae_test_gd_ridge = mean_absolute_error(y_pred_test_gd_ridge, y_test_scaled)
rmse_test_gd_ridge = root_mean_squared_error(y_pred_test_gd_ridge, y_test_scaled)
r2_test_gd_ridge = r2_score(y_pred_test_gd_ridge, y_test_scaled)


# Calcul des scores
ridge_test_gd_score_pred = {
    "Name": "Ridge",
    "Data": "Test",
    "GridSearch": True,
    "MSE": mse_test_gd_ridge,
    "MAE": mae_test_gd_ridge,
    "RMSE": rmse_test_gd_ridge,
    "R2": r2_test_gd_ridge
}

pprint(ridge_test_gd_score_pred)
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=8.85876e-20): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=1.08747e-19): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=7.96686e-20): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=1.47244e-19): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=9.21619e-20): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=8.85876e-20): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=1.08747e-19): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=7.96686e-20): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=1.47244e-19): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=9.21619e-20): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=4.93726e-20): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=6.03398e-20): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=4.8801e-20): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=6.29417e-20): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=5.66904e-20): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=4.93726e-20): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=6.03398e-20): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=4.8801e-20): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=6.29417e-20): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=5.66904e-20): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=8.78497e-19): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=1.07906e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=9.25503e-19): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=1.4655e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=9.15224e-19): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=8.78497e-19): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=1.07906e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=9.25503e-19): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=1.4655e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=9.15224e-19): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=4.93171e-19): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=6.03671e-19): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=4.8858e-19): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=6.29954e-19): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=5.66855e-19): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=4.93171e-19): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=6.03671e-19): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=4.8858e-19): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=6.29954e-19): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=5.66855e-19): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=8.50186e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=1.0011e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=7.66254e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=1.38201e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=8.75777e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=8.50186e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=1.0011e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=7.66254e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=1.38201e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=8.75777e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=4.91673e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=6.08745e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=4.94643e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=6.37103e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=5.6882e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=4.91673e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=6.08745e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=4.94643e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=6.37103e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=5.6882e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=9.19573e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=1.09063e-16): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=7.92715e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=9.68869e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=9.19573e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=1.09063e-16): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=7.92715e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=9.68869e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=5.55924e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=6.45415e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=5.27117e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=6.79731e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=5.90733e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=5.55924e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=6.45415e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=5.27117e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=6.79731e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=5.90733e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# Best params: {'alpha': 10, 'fit_intercept': True, 'max_iter': 500}
# {'Data': 'Test',
#  'GridSearch': True,
#  'MAE': 0.2172972565003355,
#  'MSE': 1.0982750287881529,
#  'Name': 'Ridge',
#  'R2': -1.050786941694195,
#  'RMSE': 1.0479861777657913}

# %%
# Score sur la prédiction des données de train avec Ridge
y_pred_train_gd_ridge = ridge_grid.predict(X_train_scaled)

# Calcul des scores
mse_train_gd_ridge = mean_squared_error(y_pred_train_gd_ridge, y_train_scaled)
mae_train_gd_ridge = mean_absolute_error(y_pred_train_gd_ridge, y_train_scaled)
rmse_train_gd_ridge = root_mean_squared_error(y_pred_train_gd_ridge, y_train_scaled)
r2_train_gd_ridge = r2_score(y_pred_train_gd_ridge, y_train_scaled)


# Calcul des scores
ridge_train_gd_score_pred = {
    "Name": "Ridge",
    "Data": "Train",
    "GridSearch": True,
    "MSE": mse_train_gd_ridge,
    "MAE": mae_train_gd_ridge,
    "RMSE": rmse_train_gd_ridge,
    "R2": r2_train_gd_ridge
}

pprint(ridge_train_gd_score_pred)
# Out:
# {'Data': 'Train',
#  'GridSearch': True,
#  'MAE': 0.15271095160892906,
#  'MSE': 0.0994350088971652,
#  'Name': 'Ridge',
#  'R2': 0.8863832991103736,
#  'RMSE': 0.31533317126043875}

# %%
ridge_best_model = ridge_grid.best_estimator_

results = permutation_importance(ridge_best_model, X_train_scaled, y_train_scaled, scoring='neg_mean_squared_error')

# get importance
importance = results.importances_mean

# summarize feature importance
for i,v in enumerate(importance):
    print('Feature: %s, Score: %.5f' % (X_train_scaled.columns.values[i],v))
# plot feature importance
plt.bar([x for x in range(len(importance))], importance)
plt.show()
# Out:
# Feature: NumberofBuildings, Score: -0.00001
# Feature: NumberofFloors, Score: 0.02683
# Feature: PropertyGFATotal, Score: 0.25278
# Feature: PropertyGFAParking, Score: 0.00123
# Feature: SteamUsekBtu, Score: 0.08173
# Feature: NaturalGasTherms, Score: 0.78096
# Feature: DefaultData, Score: 0.00002
# Feature: DistrictDensity, Score: 0.00049
# Feature: BuildingAge, Score: 0.00183
# Feature: MeanFloorGFA, Score: 0.00035
# Feature: RationParking, Score: -0.00000
# Feature: Adult Education, Score: 0.00000
# Feature: Automobile Dealership, Score: 0.00002
# Feature: Bank Branch, Score: 0.00008
# Feature: Bar/Nightclub, Score: 0.00000
# Feature: College/University, Score: 0.00001
# Feature: Convenience Store without Gas Station, Score: 0.00000
# Feature: Convention Center, Score: 0.00068
# Feature: Courthouse, Score: 0.00003
# Feature: Data Center, Score: 0.00649
# Feature: Distribution Center, Score: 0.00088
# Feature: Dry Cleaning, Score: 0.00002
# Feature: Enclosed Mall, Score: -0.00000
# Feature: Fast Food Restaurant, Score: 0.00001
# Feature: Financial Office, Score: 0.00520
# Feature: Fire Station, Score: 0.00000
# Feature: Fitness Center/Health Club/Gym, Score: 0.00017
# Feature: Food Sales, Score: 0.00009
# Feature: Food Service, Score: 0.00033
# Feature: Hospital (General Medical & Surgical), Score: 0.00011
# Feature: Hotel, Score: 0.00116
# Feature: K-12 School, Score: 0.00004
# Feature: Laboratory, Score: 0.00159
# Feature: Library, Score: 0.00003
# Feature: Lifestyle Center, Score: 0.00004
# Feature: Locksmith, Score: -0.00000
# Feature: Manufacturing/Industrial Plant, Score: -0.00000
# Feature: Medical Office, Score: 0.00025
# Feature: Movie Theater, Score: 0.00002
# Feature: Multifamily Housing, Score: 0.00063
# Feature: Museum, Score: -0.00000
# Feature: Non-Refrigerated Warehouse, Score: 0.00030
# Feature: Office, Score: 0.00413
# Feature: Other, Score: 0.00185
# Feature: Other - Education, Score: 0.00008
# Feature: Other - Entertainment/Public Assembly, Score: 0.00001
# Feature: Other - Lodging/Residential, Score: 0.00004
# Feature: Other - Mall, Score: 0.00010
# Feature: Other - Public Services, Score: 0.00003
# Feature: Other - Recreation, Score: 0.00138
# Feature: Other - Restaurant/Bar, Score: -0.00000
# Feature: Other - Services, Score: 0.00022
# Feature: Other - Technology/Science, Score: 0.00000
# Feature: Other - Utility, Score: 0.00000
# Feature: Other/Specialty Hospital, Score: -0.00000
# Feature: Outpatient Rehabilitation/Physical Therapy, Score: 0.00000
# Feature: Parking, Score: 0.00015
# Feature: Performing Arts, Score: 0.00000
# Feature: YearBuilt_1976, Score: 0.00026
# Feature: YearBuilt_1977, Score: 0.00032
# Feature: YearBuilt_1978, Score: 0.00001
# Feature: YearBuilt_1979, Score: 0.00002
# Feature: YearBuilt_1980, Score: 0.00002
# Feature: YearBuilt_1981, Score: 0.00001
# Feature: YearBuilt_1982, Score: 0.00000
# Feature: YearBuilt_1983, Score: 0.00009
# Feature: YearBuilt_1984, Score: 0.00016
# Feature: YearBuilt_1985, Score: 0.00004
# Feature: YearBuilt_1986, Score: 0.00014
# Feature: YearBuilt_1987, Score: 0.00001
# Feature: YearBuilt_1988, Score: 0.00004
# Feature: YearBuilt_1989, Score: 0.00006
# Feature: YearBuilt_1990, Score: 0.00024
# Feature: YearBuilt_1991, Score: 0.00003
# Feature: YearBuilt_1992, Score: -0.00000
# Feature: YearBuilt_1993, Score: 0.00000
# Feature: YearBuilt_1994, Score: 0.00002
# Feature: YearBuilt_1995, Score: 0.00002
# Feature: YearBuilt_1996, Score: 0.00009
# Feature: YearBuilt_1997, Score: 0.00001
# Feature: YearBuilt_1998, Score: 0.00082
# Feature: YearBuilt_1999, Score: 0.00004
# Feature: YearBuilt_2000, Score: 0.00003
# Feature: YearBuilt_2001, Score: 0.00022
# Feature: YearBuilt_2002, Score: 0.00001
# Feature: YearBuilt_2003, Score: 0.00004
# Feature: YearBuilt_2004, Score: 0.00008
# Feature: YearBuilt_2005, Score: 0.00009
# Feature: YearBuilt_2006, Score: 0.00017
# Feature: YearBuilt_2007, Score: 0.00004
# Feature: YearBuilt_2008, Score: 0.00000
# Feature: YearBuilt_2009, Score: 0.00010
# Feature: YearBuilt_2010, Score: -0.00000
# Feature: YearBuilt_2011, Score: 0.00000
# Feature: YearBuilt_2012, Score: 0.00006
# Feature: YearBuilt_2013, Score: 0.00016
# Feature: YearBuilt_2014, Score: 0.00022
# Feature: YearBuilt_2015, Score: 0.00007
# Feature: LargestPropertyUseType_Adult Education, Score: 0.00000
# Feature: LargestPropertyUseType_Automobile Dealership, Score: 0.00000
# Feature: LargestPropertyUseType_Bank Branch, Score: -0.00000
# Feature: LargestPropertyUseType_College/University, Score: 0.00001
# Feature: LargestPropertyUseType_Convention Center, Score: 0.00068
# Feature: LargestPropertyUseType_Courthouse, Score: 0.00000
# Feature: LargestPropertyUseType_Data Center, Score: 0.00150
# Feature: LargestPropertyUseType_Distribution Center, Score: 0.00049
# Feature: LargestPropertyUseType_Financial Office, Score: 0.00007
# Feature: LargestPropertyUseType_Fire Station, Score: 0.00000
# Feature: LargestPropertyUseType_Fitness Center/Health Club/Gym, Score: -0.00000
# Feature: LargestPropertyUseType_Food Service, Score: -0.00000
# Feature: LargestPropertyUseType_Hospital (General Medical & Surgical), Score: 0.00006
# Feature: LargestPropertyUseType_Hotel, Score: 0.00030
# Feature: LargestPropertyUseType_K-12 School, Score: 0.00003
# Feature: LargestPropertyUseType_Laboratory, Score: 0.00000
# Feature: LargestPropertyUseType_Library, Score: 0.00000
# Feature: LargestPropertyUseType_Lifestyle Center, Score: 0.00000
# Feature: LargestPropertyUseType_Manufacturing/Industrial Plant, Score: -0.00001
# Feature: LargestPropertyUseType_Medical Office, Score: 0.00033
# Feature: LargestPropertyUseType_Movie Theater, Score: 0.00000
# Feature: LargestPropertyUseType_Multifamily Housing, Score: 0.00021
# Feature: LargestPropertyUseType_Museum, Score: 0.00000
# Feature: LargestPropertyUseType_Non-Refrigerated Warehouse, Score: 0.00058
# Feature: LargestPropertyUseType_Office, Score: 0.00116
# Feature: LargestPropertyUseType_Other, Score: 0.00023
# Feature: LargestPropertyUseType_Other - Education, Score: 0.00000
# Feature: LargestPropertyUseType_Other - Entertainment/Public Assembly, Score: 0.00000
# Feature: LargestPropertyUseType_Other - Lodging/Residential, Score: 0.00004
# Feature: LargestPropertyUseType_Other - Mall, Score: 0.00014
# Feature: LargestPropertyUseType_Other - Public Services, Score: 0.00000
# Feature: LargestPropertyUseType_Other - Recreation, Score: 0.00070
# Feature: LargestPropertyUseType_Other - Services, Score: 0.00003
# Feature: LargestPropertyUseType_Other - Utility, Score: 0.00000
# Feature: LargestPropertyUseType_Other/Specialty Hospital, Score: -0.00000
# Feature: LargestPropertyUseType_Parking, Score: 0.00242
# Feature: LargestPropertyUseType_Performing Arts, Score: 0.00000
# Feature: LargestPropertyUseType_Pre-school/Daycare, Score: 0.00000
# Feature: LargestPropertyUseType_Refrigerated Warehouse, Score: 0.00000
# Feature: LargestPropertyUseType_Repair Services (Vehicle, Shoe, Locksmith, etc), Score: -0.00000
# Feature: LargestPropertyUseType_Residence Hall/Dormitory, Score: 0.00010
# Feature: LargestPropertyUseType_Residential Care Facility, Score: 0.00000
# Feature: LargestPropertyUseType_Restaurant, Score: 0.00007
# Feature: LargestPropertyUseType_Retail Store, Score: -0.00001
# Feature: LargestPropertyUseType_Self-Storage Facility, Score: 0.00002
# Feature: LargestPropertyUseType_Senior Care Community, Score: 0.00018
# Feature: LargestPropertyUseType_Social/Meeting Hall, Score: 0.00001
# Feature: LargestPropertyUseType_Strip Mall, Score: 0.00002
# Feature: LargestPropertyUseType_Supermarket/Grocery Store, Score: 0.00007
# Feature: LargestPropertyUseType_Urgent Care/Clinic/Other Outpatient, Score: 0.00084
# Feature: LargestPropertyUseType_Wholesale Club/Supercenter, Score: 0.00000
# Feature: LargestPropertyUseType_Worship Facility, Score: 0.00025
# Feature: LargestPropertyUseType_nan, Score: 0.00000
# Feature: SecondLargestPropertyUseType_Automobile Dealership, Score: 0.00001
# Feature: SecondLargestPropertyUseType_Bank Branch, Score: -0.00000
# Feature: SecondLargestPropertyUseType_Bar/Nightclub, Score: -0.00000
# Feature: SecondLargestPropertyUseType_Courthouse, Score: 0.00001
# Feature: SecondLargestPropertyUseType_Data Center, Score: 0.00197
# Feature: SecondLargestPropertyUseType_Distribution Center, Score: 0.00030
# Feature: SecondLargestPropertyUseType_Enclosed Mall, Score: -0.00000
# Feature: SecondLargestPropertyUseType_Financial Office, Score: 0.00003
# Feature: SecondLargestPropertyUseType_Fitness Center/Health Club/Gym, Score: 0.00001
# Feature: SecondLargestPropertyUseType_Food Service, Score: 0.00001
# Feature: SecondLargestPropertyUseType_Hospital (General Medical & Surgical), Score: 0.00000
# Feature: SecondLargestPropertyUseType_Hotel, Score: 0.00013
# Feature: SecondLargestPropertyUseType_K-12 School, Score: 0.00000
# Feature: SecondLargestPropertyUseType_Laboratory, Score: 0.00020
# Feature: SecondLargestPropertyUseType_Manufacturing/Industrial Plant, Score: 0.00001
# Feature: SecondLargestPropertyUseType_Medical Office, Score: 0.00001
# Feature: SecondLargestPropertyUseType_Movie Theater, Score: 0.00004
# Feature: SecondLargestPropertyUseType_Multifamily Housing, Score: 0.00002
# Feature: SecondLargestPropertyUseType_Non-Refrigerated Warehouse, Score: 0.00002
# Feature: SecondLargestPropertyUseType_Office, Score: 0.00004
# Feature: SecondLargestPropertyUseType_Other, Score: 0.00070
# Feature: SecondLargestPropertyUseType_Other - Education, Score: -0.00000
# Feature: SecondLargestPropertyUseType_Other - Entertainment/Public Assembly, Score: 0.00000
# Feature: SecondLargestPropertyUseType_Other - Lodging/Residential, Score: 0.00000
# Feature: SecondLargestPropertyUseType_Other - Public Services, Score: 0.00003
# Feature: SecondLargestPropertyUseType_Other - Recreation, Score: -0.00001
# Feature: SecondLargestPropertyUseType_Other - Restaurant/Bar, Score: -0.00000
# Feature: SecondLargestPropertyUseType_Other - Services, Score: 0.00012
# Feature: SecondLargestPropertyUseType_Parking, Score: 0.00009
# Feature: SecondLargestPropertyUseType_Performing Arts, Score: 0.00001
# Feature: SecondLargestPropertyUseType_Personal Services (Health/Beauty, Dry Cleaning, etc), Score: 0.00000
# Feature: SecondLargestPropertyUseType_Pre-school/Daycare, Score: 0.00000
# Feature: SecondLargestPropertyUseType_Refrigerated Warehouse, Score: 0.00031
# Feature: SecondLargestPropertyUseType_Repair Services (Vehicle, Shoe, Locksmith, etc), Score: 0.00000
# Feature: SecondLargestPropertyUseType_Residence Hall/Dormitory, Score: -0.00000
# Feature: SecondLargestPropertyUseType_Restaurant, Score: 0.00046
# Feature: SecondLargestPropertyUseType_Retail Store, Score: 0.00001
# Feature: SecondLargestPropertyUseType_Self-Storage Facility, Score: 0.00000
# Feature: SecondLargestPropertyUseType_Supermarket/Grocery Store, Score: 0.00002
# Feature: SecondLargestPropertyUseType_Swimming Pool, Score: -0.00000
# Feature: SecondLargestPropertyUseType_Vocational School, Score: -0.00000
# Feature: SecondLargestPropertyUseType_Worship Facility, Score: -0.00000
# Feature: SecondLargestPropertyUseType_nan, Score: 0.00095
# Feature: ThirdLargestPropertyUseType_Bank Branch, Score: 0.00009
# Feature: ThirdLargestPropertyUseType_Bar/Nightclub, Score: 0.00000
# Feature: ThirdLargestPropertyUseType_Convenience Store without Gas Station, Score: 0.00001
# Feature: ThirdLargestPropertyUseType_Data Center, Score: -0.00000
# Feature: ThirdLargestPropertyUseType_Distribution Center, Score: 0.00003
# Feature: ThirdLargestPropertyUseType_Fast Food Restaurant, Score: -0.00000
# Feature: ThirdLargestPropertyUseType_Financial Office, Score: 0.00039
# Feature: ThirdLargestPropertyUseType_Fitness Center/Health Club/Gym, Score: 0.00001
# Feature: ThirdLargestPropertyUseType_Food Service, Score: 0.00009
# Feature: ThirdLargestPropertyUseType_Hotel, Score: 0.00000
# Feature: ThirdLargestPropertyUseType_K-12 School, Score: 0.00000
# Feature: ThirdLargestPropertyUseType_Laboratory, Score: -0.00000
# Feature: ThirdLargestPropertyUseType_Medical Office, Score: 0.00003
# Feature: ThirdLargestPropertyUseType_Multifamily Housing, Score: 0.00001
# Feature: ThirdLargestPropertyUseType_Non-Refrigerated Warehouse, Score: 0.00000
# Feature: ThirdLargestPropertyUseType_Office, Score: 0.00043
# Feature: ThirdLargestPropertyUseType_Other, Score: 0.00108
# Feature: ThirdLargestPropertyUseType_Other - Education, Score: 0.00001
# Feature: ThirdLargestPropertyUseType_Other - Entertainment/Public Assembly, Score: 0.00001
# Feature: ThirdLargestPropertyUseType_Other - Recreation, Score: 0.00000
# Feature: ThirdLargestPropertyUseType_Other - Restaurant/Bar, Score: 0.00004
# Feature: ThirdLargestPropertyUseType_Other - Services, Score: -0.00000
# Feature: ThirdLargestPropertyUseType_Other - Technology/Science, Score: 0.00006
# Feature: ThirdLargestPropertyUseType_Parking, Score: 0.00004
# Feature: ThirdLargestPropertyUseType_Personal Services (Health/Beauty, Dry Cleaning, etc), Score: 0.00007
# Feature: ThirdLargestPropertyUseType_Pre-school/Daycare, Score: 0.00000
# Feature: ThirdLargestPropertyUseType_Refrigerated Warehouse, Score: 0.00005
# Feature: ThirdLargestPropertyUseType_Restaurant, Score: 0.00001
# Feature: ThirdLargestPropertyUseType_Retail Store, Score: 0.00019
# Feature: ThirdLargestPropertyUseType_Self-Storage Facility, Score: 0.00001
# Feature: ThirdLargestPropertyUseType_Social/Meeting Hall, Score: -0.00000
# Feature: ThirdLargestPropertyUseType_Supermarket/Grocery Store, Score: -0.00000
# Feature: ThirdLargestPropertyUseType_Swimming Pool, Score: 0.00005
# Feature: ThirdLargestPropertyUseType_Worship Facility, Score: 0.00000
# Feature: ThirdLargestPropertyUseType_nan, Score: 0.00031
# Feature: ComplianceStatus_Compliant, Score: 0.00075
# Feature: ComplianceStatus_Error - Correct Default Data, Score: 0.00002
# Feature: ComplianceStatus_Missing Data, Score: 0.00000
# Feature: ComplianceStatus_Non-Compliant, Score: 0.00068

# %% [markdown]
# SVR

# %%
# SVR

params = {
    'kernel': ['rbf'],
    'C': [1, 10],  
    'gamma': ['scale', 0.1],
    'epsilon': [0.1]
}

# Initialisation SVR
svr = SVR(cache_size=1000, max_iter=1000)

grid = GridSearchCV(svr, params, cv=5)
grid.fit(X_train_scaled, y_train_scaled)
print(f"Best params: {grid.best_params_}")

# Tous les scores
scores_df = pd.DataFrame(grid.cv_results_)

y_pred_test_gd_svr = grid.predict(X_test_scaled)

mse_test_gd_svr = mean_squared_error(y_pred_test_gd_svr, y_test_scaled)
mae_test_gd_svr = mean_absolute_error(y_pred_test_gd_svr, y_test_scaled)
rmse_test_gd_svr = root_mean_squared_error(y_pred_test_gd_svr, y_test_scaled)
r2_test_gd_svr = r2_score(y_pred_test_gd_svr, y_test_scaled)


svr_test_gd_score_pred = {
    "Name": "SVR",
    "Data": "Test",
    "GridSearch": True,
    "MSE": mse_test_gd_svr,
    "MAE": mae_test_gd_svr,
    "RMSE": rmse_test_gd_svr,
    "R2": r2_test_gd_svr
}

pprint(svr_test_gd_score_pred)

svr_best_model = grid.best_estimator_
joblib.dump(svr_best_model, 'model/svr.model')
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# Best params: {'C': 10, 'epsilon': 0.1, 'gamma': 'scale', 'kernel': 'rbf'}
# {'Data': 'Test',
#  'GridSearch': True,
#  'MAE': 0.20620867566842085,
#  'MSE': 1.2103622680228283,
#  'Name': 'SVR',
#  'R2': -1.7956086210527507,
#  'RMSE': 1.1001646549598056}
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# ['model/svr.model']

# %%
# Score sur la prédiction des données de train avec SVR
y_pred_train_gd_svr = grid.predict(X_train_scaled)

mse_train_gd_svr = mean_squared_error(y_pred_train_gd_svr, y_train_scaled)
mae_train_gd_svr = mean_absolute_error(y_pred_train_gd_svr, y_train_scaled)
rmse_train_gd_svr = root_mean_squared_error(y_pred_train_gd_svr, y_train_scaled)
r2_train_gd_svr = r2_score(y_pred_train_gd_svr, y_train_scaled)


svr_train_gd_score_pred = {
    "Name": "SVR",
    "Data": "Train",
    "GridSearch": True,
    "MSE": mse_train_gd_svr,
    "MAE": mae_train_gd_svr,
    "RMSE": rmse_train_gd_svr,
    "R2": r2_train_gd_svr
}

pprint(svr_train_gd_score_pred)
# Out:
# {'Data': 'Train',
#  'GridSearch': True,
#  'MAE': 0.16599017178295322,
#  'MSE': 0.16913074022000169,
#  'Name': 'SVR',
#  'R2': 0.7604967740818294,
#  'RMSE': 0.41125507926346844}

# %%
best_model = grid.best_estimator_

results = permutation_importance(best_model, X_train_scaled, y_train_scaled, scoring='neg_mean_squared_error')

# get importance
importance = results.importances_mean

# %%
# summarize feature importance
for i,v in enumerate(importance):
    print('Feature: %s, Score: %.5f' % (X_train_scaled.columns.values[i],v))
# plot feature importance
plt.bar([x for x in range(len(importance))], importance)
plt.show()
# Out:
# Feature: NumberofBuildings, Score: 0.00000
# Feature: NumberofFloors, Score: 0.00000
# Feature: PropertyGFATotal, Score: 0.49145
# Feature: PropertyGFAParking, Score: 0.00038
# Feature: SteamUsekBtu, Score: 0.14152
# Feature: NaturalGasTherms, Score: 0.66089
# Feature: DefaultData, Score: 0.00000
# Feature: DistrictDensity, Score: 0.00011
# Feature: BuildingAge, Score: 0.00000
# Feature: MeanFloorGFA, Score: 0.00184
# Feature: RationParking, Score: 0.00000
# Feature: Adult Education, Score: -0.00000
# Feature: Automobile Dealership, Score: -0.00000
# Feature: Bank Branch, Score: 0.00000
# Feature: Bar/Nightclub, Score: -0.00000
# Feature: College/University, Score: 0.00000
# Feature: Convenience Store without Gas Station, Score: 0.00000
# Feature: Convention Center, Score: 0.00000
# Feature: Courthouse, Score: 0.00000
# Feature: Data Center, Score: 0.00000
# Feature: Distribution Center, Score: 0.00000
# Feature: Dry Cleaning, Score: 0.00000
# Feature: Enclosed Mall, Score: 0.00000
# Feature: Fast Food Restaurant, Score: 0.00000
# Feature: Financial Office, Score: 0.00000
# Feature: Fire Station, Score: -0.00000
# Feature: Fitness Center/Health Club/Gym, Score: 0.00000
# Feature: Food Sales, Score: 0.00000
# Feature: Food Service, Score: 0.00000
# Feature: Hospital (General Medical & Surgical), Score: 0.00000
# Feature: Hotel, Score: 0.00000
# Feature: K-12 School, Score: 0.00000
# Feature: Laboratory, Score: 0.00000
# Feature: Library, Score: -0.00000
# Feature: Lifestyle Center, Score: 0.00000
# Feature: Locksmith, Score: -0.00000
# Feature: Manufacturing/Industrial Plant, Score: 0.00000
# Feature: Medical Office, Score: 0.00000
# Feature: Movie Theater, Score: 0.00000
# Feature: Multifamily Housing, Score: 0.00000
# Feature: Museum, Score: 0.00000
# Feature: Non-Refrigerated Warehouse, Score: 0.00000
# Feature: Office, Score: 0.00000
# Feature: Other, Score: 0.00000
# Feature: Other - Education, Score: 0.00000
# Feature: Other - Entertainment/Public Assembly, Score: 0.00000
# Feature: Other - Lodging/Residential, Score: 0.00000
# Feature: Other - Mall, Score: 0.00000
# Feature: Other - Public Services, Score: 0.00000
# Feature: Other - Recreation, Score: -0.00000
# Feature: Other - Restaurant/Bar, Score: 0.00000
# Feature: Other - Services, Score: -0.00000
# Feature: Other - Technology/Science, Score: -0.00000
# Feature: Other - Utility, Score: 0.00000
# Feature: Other/Specialty Hospital, Score: 0.00000
# Feature: Outpatient Rehabilitation/Physical Therapy, Score: 0.00000
# Feature: Parking, Score: 0.00000
# Feature: Performing Arts, Score: 0.00000
# Feature: Personal Services (Health/Beauty, Score: 0.00000
# Feature: Pre-school/Daycare, Score: -0.00000
# Feature: Refrigerated Warehouse, Score: 0.00000
# Feature: Repair Services (Vehicle, Score: -0.00000
# Feature: Residence Hall/Dormitory, Score: 0.00000
# Feature: Residential Care Facility, Score: 0.00000
# Feature: Restaurant, Score: 0.00000
# Feature: Retail Store, Score: -0.00000
# Feature: Self-Storage Facility, Score: 0.00000
# Feature: Senior Care Community, Score: 0.00000
# Feature: Shoe, Score: -0.00000
# Feature: Social/Meeting Hall, Score: 0.00000
# Feature: Strip Mall, Score: 0.00000
# Feature: Supermarket/Grocery Store, Score: 0.00000
# Feature: Swimming Pool, Score: 0.00000
# Feature: Urgent Care/Clinic/Other Outpatient, Score: 0.00000
# Feature: Vocat, Score: 0.00000
# Feature: Vocational School, Score: -0.00000
# Feature: Wholesale Club/Supercenter, Score: 0.00000
# Feature: Worship Facility, Score: 0.00000
# Feature: etc), Score: 0.00000
# Feature: BuildingType_NonResidential, Score: -0.00000
# Feature: BuildingType_Nonresidential COS, Score: -0.00000
# Feature: BuildingType_Nonresidential WA, Score: 0.00000
# Feature: PrimaryPropertyType_Distribution Center, Score: 0.00000
# Feature: PrimaryPropertyType_Hospital, Score: 0.00000
# Feature: PrimaryPropertyType_Hotel, Score: 0.00000
# Feature: PrimaryPropertyType_K-12 School, Score: 0.00000
# Feature: PrimaryPropertyType_Laboratory, Score: 0.00000
# Feature: PrimaryPropertyType_Large Office, Score: 0.00000
# Feature: PrimaryPropertyType_Low-Rise Multifamily, Score: 0.00000
# Feature: PrimaryPropertyType_Medical Office, Score: 0.00000
# Feature: PrimaryPropertyType_Mixed Use Property, Score: 0.00000
# Feature: PrimaryPropertyType_Other, Score: 0.00000
# Feature: PrimaryPropertyType_Refrigerated Warehouse, Score: 0.00000
# Feature: PrimaryPropertyType_Residence Hall, Score: 0.00000
# Feature: PrimaryPropertyType_Restaurant, Score: 0.00000
# Feature: PrimaryPropertyType_Retail Store, Score: 0.00000
# Feature: PrimaryPropertyType_Self-Storage Facility, Score: 0.00000
# Feature: PrimaryPropertyType_Senior Care Community, Score: 0.00000
# Feature: PrimaryPropertyType_Small- and Mid-Sized Office, Score: -0.00000
# Feature: PrimaryPropertyType_Supermarket / Grocery Store, Score: 0.00000
# Feature: PrimaryPropertyType_University, Score: 0.00000
# Feature: PrimaryPropertyType_Warehouse, Score: 0.00000
# Feature: PrimaryPropertyType_Worship Facility, Score: 0.00000
# Feature: ZipCode_98013, Score: 0.00000
# Feature: Neighborhood_North, Score: 0.00000
# Feature: Neighborhood_Northwest, Score: 0.00000
# Feature: Neighborhood_SOUTHEAST, Score: -0.00000
# Feature: Neighborhood_SOUTHWEST, Score: 0.00000
# Feature: YearBuilt_1900, Score: 0.00000
# Feature: YearBuilt_1901, Score: -0.00000
# Feature: YearBuilt_1902, Score: 0.00000
# Feature: YearBuilt_1903, Score: -0.00000
# Feature: YearBuilt_1904, Score: 0.00000
# Feature: YearBuilt_1905, Score: -0.00000
# Feature: YearBuilt_1906, Score: 0.00000
# Feature: YearBuilt_1907, Score: 0.00000
# Feature: YearBuilt_1908, Score: 0.00000
# Feature: YearBuilt_1909, Score: 0.00000
# Feature: YearBuilt_1910, Score: 0.00000
# Feature: YearBuilt_1911, Score: -0.00000
# Feature: YearBuilt_1912, Score: -0.00000
# Feature: YearBuilt_1913, Score: -0.00000
# Feature: YearBuilt_1914, Score: 0.00000
# Feature: YearBuilt_1915, Score: -0.00000
# Feature: YearBuilt_1916, Score: 0.00000
# Feature: YearBuilt_1917, Score: 0.00000
# Feature: YearBuilt_1918, Score: -0.00000
# Feature: YearBuilt_1919, Score: -0.00000
# Feature: YearBuilt_1920, Score: 0.00000
# Feature: YearBuilt_1921, Score: -0.00000
# Feature: YearBuilt_1922, Score: 0.00000
# Feature: YearBuilt_1923, Score: 0.00000
# Feature: YearBuilt_1924, Score: 0.00000
# Feature: YearBuilt_1925, Score: 0.00000
# Feature: YearBuilt_1926, Score: -0.00000
# Feature: YearBuilt_1927, Score: -0.00000
# Feature: YearBuilt_1928, Score: 0.00000
# Feature: YearBuilt_1929, Score: -0.00000
# Feature: YearBuilt_1930, Score: 0.00000
# Feature: YearBuilt_1931, Score: -0.00000
# Feature: YearBuilt_1932, Score: 0.00000
# Feature: YearBuilt_1935, Score: 0.00000
# Feature: YearBuilt_1937, Score: 0.00000
# Feature: YearBuilt_1938, Score: 0.00000
# Feature: YearBuilt_1940, Score: -0.00000
# Feature: YearBuilt_1941, Score: -0.00000
# Feature: YearBuilt_1942, Score: 0.00000
# Feature: YearBuilt_1944, Score: 0.00000
# Feature: YearBuilt_1945, Score: 0.00000
# Feature: YearBuilt_1946, Score: 0.00000
# Feature: YearBuilt_1947, Score: -0.00000
# Feature: YearBuilt_1948, Score: 0.00000
# Feature: YearBuilt_1949, Score: 0.00000
# Feature: YearBuilt_1950, Score: -0.00000
# Feature: YearBuilt_1951, Score: 0.00000
# Feature: YearBuilt_1952, Score: 0.00000
# Feature: YearBuilt_1953, Score: 0.00000
# Feature: YearBuilt_1954, Score: 0.00000
# Feature: YearBuilt_1955, Score: -0.00000
# Feature: YearBuilt_1956, Score: -0.00000
# Feature: YearBuilt_1957, Score: -0.00000
# Feature: YearBuilt_1958, Score: -0.00000
# Feature: YearBuilt_1959, Score: 0.00000
# Feature: YearBuilt_1960, Score: -0.00000
# Feature: YearBuilt_1961, Score: 0.00000
# Feature: YearBuilt_1962, Score: 0.00000
# Feature: YearBuilt_1963, Score: -0.00000
# Feature: YearBuilt_1964, Score: -0.00000
# Feature: YearBuilt_1965, Score: -0.00000
# Feature: YearBuilt_1966, Score: -0.00000
# Feature: YearBuilt_1967, Score: 0.00000
# Feature: YearBuilt_1968, Score: 0.00000
# Feature: YearBuilt_1969, Score: 0.00000
# Feature: YearBuilt_1970, Score: 0.00000
# Feature: YearBuilt_1971, Score: 0.00000
# Feature: YearBuilt_1972, Score: 0.00000
# Feature: YearBuilt_1973, Score: 0.00000
# Feature: YearBuilt_1974, Score: -0.00000
# Feature: YearBuilt_1975, Score: 0.00000
# Feature: YearBuilt_1976, Score: 0.00000
# Feature: YearBuilt_1977, Score: 0.00000
# Feature: YearBuilt_1978, Score: 0.00000
# Feature: YearBuilt_1979, Score: 0.00000
# Feature: YearBuilt_1980, Score: 0.00000
# Feature: YearBuilt_1981, Score: -0.00000
# Feature: YearBuilt_1982, Score: -0.00000
# Feature: YearBuilt_1983, Score: 0.00000
# Feature: YearBuilt_1984, Score: 0.00000
# Feature: YearBuilt_1985, Score: 0.00000
# Feature: YearBuilt_1986, Score: -0.00000
# Feature: YearBuilt_1987, Score: 0.00000
# Feature: YearBuilt_1988, Score: 0.00000
# Feature: YearBuilt_1989, Score: -0.00000
# Feature: YearBuilt_1990, Score: -0.00000
# Feature: YearBuilt_1991, Score: 0.00000
# Feature: YearBuilt_1992, Score: -0.00000
# Feature: YearBuilt_1993, Score: -0.00000
# Feature: YearBuilt_1994, Score: 0.00000
# Feature: YearBuilt_1995, Score: 0.00000
# Feature: YearBuilt_1996, Score: -0.00000
# Feature: YearBuilt_1997, Score: 0.00000
# Feature: YearBuilt_1998, Score: 0.00000
# Feature: YearBuilt_1999, Score: 0.00000
# Feature: YearBuilt_2000, Score: 0.00000
# Feature: YearBuilt_2001, Score: -0.00000
# Feature: YearBuilt_2002, Score: 0.00000
# Feature: YearBuilt_2003, Score: 0.00000
# Feature: YearBuilt_2004, Score: -0.00000
# Feature: YearBuilt_2005, Score: 0.00000
# Feature: YearBuilt_2006, Score: 0.00000
# Feature: YearBuilt_2007, Score: 0.00000
# Feature: YearBuilt_2008, Score: 0.00000
# Feature: YearBuilt_2009, Score: -0.00000
# Feature: YearBuilt_2010, Score: 0.00000
# Feature: YearBuilt_2011, Score: 0.00000
# Feature: YearBuilt_2012, Score: 0.00000
# Feature: YearBuilt_2013, Score: 0.00000
# Feature: YearBuilt_2014, Score: 0.00000
# Feature: YearBuilt_2015, Score: 0.00000
# Feature: LargestPropertyUseType_Adult Education, Score: -0.00000
# Feature: LargestPropertyUseType_Automobile Dealership, Score: -0.00000
# Feature: LargestPropertyUseType_Bank Branch, Score: -0.00000
# Feature: LargestPropertyUseType_College/University, Score: 0.00000
# Feature: LargestPropertyUseType_Convention Center, Score: 0.00000
# Feature: LargestPropertyUseType_Courthouse, Score: 0.00000
# Feature: LargestPropertyUseType_Data Center, Score: 0.00000
# Feature: LargestPropertyUseType_Distribution Center, Score: 0.00000
# Feature: LargestPropertyUseType_Financial Office, Score: 0.00000
# Feature: LargestPropertyUseType_Fire Station, Score: -0.00000
# Feature: LargestPropertyUseType_Fitness Center/Health Club/Gym, Score: 0.00000
# Feature: LargestPropertyUseType_Food Service, Score: -0.00000
# Feature: LargestPropertyUseType_Hospital (General Medical & Surgical), Score: 0.00000
# Feature: LargestPropertyUseType_Hotel, Score: 0.00000
# Feature: LargestPropertyUseType_K-12 School, Score: 0.00000
# Feature: LargestPropertyUseType_Laboratory, Score: 0.00000
# Feature: LargestPropertyUseType_Library, Score: -0.00000
# Feature: LargestPropertyUseType_Lifestyle Center, Score: 0.00000
# Feature: LargestPropertyUseType_Manufacturing/Industrial Plant, Score: 0.00000
# Feature: LargestPropertyUseType_Medical Office, Score: 0.00000
# Feature: LargestPropertyUseType_Movie Theater, Score: -0.00000
# Feature: LargestPropertyUseType_Multifamily Housing, Score: 0.00000
# Feature: LargestPropertyUseType_Museum, Score: 0.00000
# Feature: LargestPropertyUseType_Non-Refrigerated Warehouse, Score: 0.00000
# Feature: LargestPropertyUseType_Office, Score: 0.00000
# Feature: LargestPropertyUseType_Other, Score: 0.00000
# Feature: LargestPropertyUseType_Other - Education, Score: 0.00000
# Feature: LargestPropertyUseType_Other - Entertainment/Public Assembly, Score: 0.00000
# Feature: LargestPropertyUseType_Other - Lodging/Residential, Score: 0.00000
# Feature: LargestPropertyUseType_Other - Mall, Score: 0.00000
# Feature: LargestPropertyUseType_Other - Public Services, Score: 0.00000
# Feature: LargestPropertyUseType_Other - Recreation, Score: -0.00000
# Feature: LargestPropertyUseType_Other - Services, Score: 0.00000
# Feature: LargestPropertyUseType_Other - Utility, Score: 0.00000
# Feature: LargestPropertyUseType_Other/Specialty Hospital, Score: 0.00000
# Feature: LargestPropertyUseType_Parking, Score: -0.00000
# Feature: LargestPropertyUseType_Performing Arts, Score: -0.00000
# Feature: LargestPropertyUseType_Pre-school/Daycare, Score: -0.00000
# Feature: LargestPropertyUseType_Refrigerated Warehouse, Score: 0.00000
# Feature: LargestPropertyUseType_Repair Services (Vehicle, Shoe, Locksmith, etc), Score: -0.00000
# Feature: LargestPropertyUseType_Residence Hall/Dormitory, Score: 0.00000
# Feature: LargestPropertyUseType_Residential Care Facility, Score: 0.00000
# Feature: LargestPropertyUseType_Restaurant, Score: 0.00000
# Feature: LargestPropertyUseType_Retail Store, Score: 0.00000
# Feature: LargestPropertyUseType_Self-Storage Facility, Score: 0.00000
# Feature: LargestPropertyUseType_Senior Care Community, Score: 0.00000
# Feature: LargestPropertyUseType_Social/Meeting Hall, Score: 0.00000
# Feature: LargestPropertyUseType_Strip Mall, Score: 0.00000
# Feature: LargestPropertyUseType_Supermarket/Grocery Store, Score: 0.00000
# Feature: LargestPropertyUseType_Urgent Care/Clinic/Other Outpatient, Score: 0.00000
# Feature: LargestPropertyUseType_Wholesale Club/Supercenter, Score: 0.00000
# Feature: LargestPropertyUseType_Worship Facility, Score: 0.00000
# Feature: LargestPropertyUseType_nan, Score: 0.00000
# Feature: SecondLargestPropertyUseType_Automobile Dealership, Score: 0.00000
# Feature: SecondLargestPropertyUseType_Bank Branch, Score: 0.00000
# Feature: SecondLargestPropertyUseType_Bar/Nightclub, Score: -0.00000
# Feature: SecondLargestPropertyUseType_Courthouse, Score: -0.00000
# Feature: SecondLargestPropertyUseType_Data Center, Score: 0.00000
# Feature: SecondLargestPropertyUseType_Distribution Center, Score: 0.00000
# Feature: SecondLargestPropertyUseType_Enclosed Mall, Score: 0.00000
# Feature: SecondLargestPropertyUseType_Financial Office, Score: 0.00000
# Feature: SecondLargestPropertyUseType_Fitness Center/Health Club/Gym, Score: -0.00000
# Feature: SecondLargestPropertyUseType_Food Service, Score: 0.00000
# Feature: SecondLargestPropertyUseType_Hospital (General Medical & Surgical), Score: 0.00000
# Feature: SecondLargestPropertyUseType_Hotel, Score: 0.00000
# Feature: SecondLargestPropertyUseType_K-12 School, Score: 0.00000
# Feature: SecondLargestPropertyUseType_Laboratory, Score: 0.00000
# Feature: SecondLargestPropertyUseType_Manufacturing/Industrial Plant, Score: 0.00000
# Feature: SecondLargestPropertyUseType_Medical Office, Score: 0.00000
# Feature: SecondLargestPropertyUseType_Movie Theater, Score: 0.00000
# Feature: SecondLargestPropertyUseType_Multifamily Housing, Score: -0.00000
# Feature: SecondLargestPropertyUseType_Non-Refrigerated Warehouse, Score: 0.00000
# Feature: SecondLargestPropertyUseType_Office, Score: 0.00000
# Feature: SecondLargestPropertyUseType_Other, Score: 0.00000
# Feature: SecondLargestPropertyUseType_Other - Education, Score: 0.00000
# Feature: SecondLargestPropertyUseType_Other - Entertainment/Public Assembly, Score: 0.00000
# Feature: SecondLargestPropertyUseType_Other - Lodging/Residential, Score: 0.00000
# Feature: SecondLargestPropertyUseType_Other - Public Services, Score: 0.00000
# Feature: SecondLargestPropertyUseType_Other - Recreation, Score: 0.00000
# Feature: SecondLargestPropertyUseType_Other - Restaurant/Bar, Score: 0.00000
# Feature: SecondLargestPropertyUseType_Other - Services, Score: -0.00000
# Feature: SecondLargestPropertyUseType_Parking, Score: 0.00000
# Feature: SecondLargestPropertyUseType_Performing Arts, Score: 0.00000
# Feature: SecondLargestPropertyUseType_Personal Services (Health/Beauty, Dry Cleaning, etc), Score: 0.00000
# Feature: SecondLargestPropertyUseType_Pre-school/Daycare, Score: -0.00000
# Feature: SecondLargestPropertyUseType_Refrigerated Warehouse, Score: 0.00000
# Feature: SecondLargestPropertyUseType_Repair Services (Vehicle, Shoe, Locksmith, etc), Score: -0.00000
# Feature: SecondLargestPropertyUseType_Residence Hall/Dormitory, Score: 0.00000
# Feature: SecondLargestPropertyUseType_Restaurant, Score: 0.00000
# Feature: SecondLargestPropertyUseType_Retail Store, Score: -0.00000
# Feature: SecondLargestPropertyUseType_Self-Storage Facility, Score: -0.00000
# Feature: SecondLargestPropertyUseType_Supermarket/Grocery Store, Score: 0.00000
# Feature: SecondLargestPropertyUseType_Swimming Pool, Score: -0.00000
# Feature: SecondLargestPropertyUseType_Vocational School, Score: -0.00000
# Feature: SecondLargestPropertyUseType_Worship Facility, Score: 0.00000
# Feature: SecondLargestPropertyUseType_nan, Score: 0.00000
# Feature: ThirdLargestPropertyUseType_Bank Branch, Score: 0.00000
# Feature: ThirdLargestPropertyUseType_Bar/Nightclub, Score: 0.00000
# Feature: ThirdLargestPropertyUseType_Convenience Store without Gas Station, Score: 0.00000
# Feature: ThirdLargestPropertyUseType_Data Center, Score: 0.00000
# Feature: ThirdLargestPropertyUseType_Distribution Center, Score: 0.00000
# Feature: ThirdLargestPropertyUseType_Fast Food Restaurant, Score: -0.00000
# Feature: ThirdLargestPropertyUseType_Financial Office, Score: 0.00000
# Feature: ThirdLargestPropertyUseType_Fitness Center/Health Club/Gym, Score: 0.00000
# Feature: ThirdLargestPropertyUseType_Food Service, Score: 0.00000
# Feature: ThirdLargestPropertyUseType_Hotel, Score: 0.00000
# Feature: ThirdLargestPropertyUseType_K-12 School, Score: 0.00000
# Feature: ThirdLargestPropertyUseType_Laboratory, Score: 0.00000
# Feature: ThirdLargestPropertyUseType_Medical Office, Score: 0.00000
# Feature: ThirdLargestPropertyUseType_Multifamily Housing, Score: 0.00000
# Feature: ThirdLargestPropertyUseType_Non-Refrigerated Warehouse, Score: 0.00000
# Feature: ThirdLargestPropertyUseType_Office, Score: 0.00000
# Feature: ThirdLargestPropertyUseType_Other, Score: 0.00000
# Feature: ThirdLargestPropertyUseType_Other - Education, Score: 0.00000
# Feature: ThirdLargestPropertyUseType_Other - Entertainment/Public Assembly, Score: 0.00000
# Feature: ThirdLargestPropertyUseType_Other - Recreation, Score: -0.00000
# Feature: ThirdLargestPropertyUseType_Other - Restaurant/Bar, Score: 0.00000
# Feature: ThirdLargestPropertyUseType_Other - Services, Score: 0.00000
# Feature: ThirdLargestPropertyUseType_Other - Technology/Science, Score: 0.00000
# Feature: ThirdLargestPropertyUseType_Parking, Score: 0.00000
# Feature: ThirdLargestPropertyUseType_Personal Services (Health/Beauty, Dry Cleaning, etc), Score: 0.00000
# Feature: ThirdLargestPropertyUseType_Pre-school/Daycare, Score: 0.00000
# Feature: ThirdLargestPropertyUseType_Refrigerated Warehouse, Score: 0.00000
# Feature: ThirdLargestPropertyUseType_Restaurant, Score: 0.00000
# Feature: ThirdLargestPropertyUseType_Retail Store, Score: 0.00000
# Feature: ThirdLargestPropertyUseType_Self-Storage Facility, Score: 0.00000
# Feature: ThirdLargestPropertyUseType_Social/Meeting Hall, Score: 0.00000
# Feature: ThirdLargestPropertyUseType_Supermarket/Grocery Store, Score: -0.00000
# Feature: ThirdLargestPropertyUseType_Swimming Pool, Score: 0.00000
# Feature: ThirdLargestPropertyUseType_Worship Facility, Score: 0.00000
# Feature: ThirdLargestPropertyUseType_nan, Score: 0.00000
# Feature: ComplianceStatus_Compliant, Score: 0.00000
# Feature: ComplianceStatus_Error - Correct Default Data, Score: 0.00000
# Feature: ComplianceStatus_Missing Data, Score: -0.00000
# Feature: ComplianceStatus_Non-Compliant, Score: 0.00000

# %% [markdown]
# RandomForestRegressor

# %%
# RandomForestRegressor


# Définition de la grille de paramètres à tester
params = {
    'n_estimators': [200, 300, 400],
    'max_depth': [15, 20, 30, None],
    'min_samples_split': [5, 10, 15],
    'min_samples_leaf': [2, 4, 6],
    'max_features': ['sqrt', 'log2', 0.3, 0.5]
}


rf_grid = GridSearchCV(
    estimator=random_forest,
    param_grid=params,
    cv=5,         
    n_jobs=-1,         
    scoring='r2',     
)

rf_grid.fit(X_train_scaled, y_train_scaled)
print(f"Best params: {grid.best_params_}")

# Tous les scores
scores_df = pd.DataFrame(grid.cv_results_)

y_pred_test_gd_random_forest = rf_grid.predict(X_test_scaled)


mse_test_gd_random_forest = mean_squared_error(y_pred_test_gd_random_forest, y_test_scaled)
mae_test_gd_random_forest = mean_absolute_error(y_pred_test_gd_random_forest, y_test_scaled)
rmse_test_gd_random_forest = root_mean_squared_error(y_pred_test_gd_random_forest, y_test_scaled)
r2_test_gd_random_forest = r2_score(y_pred_test_gd_random_forest, y_test_scaled)


# Calcul des scores
random_forest_test_gd_score_pred = {
    "Name": "Random Forest",
    "Data": "Test",
    "GridSearch": True,
    "MSE": mse_test_gd_random_forest,
    "MAE": mae_test_gd_random_forest,
    "RMSE": rmse_test_gd_random_forest,
    "R2": r2_test_gd_random_forest
}

pprint(random_forest_test_gd_score_pred)


rf_best_model = rf_grid.best_estimator_
joblib.dump(rf_best_model, 'model/rf.model')
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/numpy/ma/core.py:2820: RuntimeWarning: invalid value encountered in cast
#   _data = np.array(data, dtype=dtype, copy=copy,
# Best params: {'C': 10, 'epsilon': 0.1, 'gamma': 'scale', 'kernel': 'rbf'}
# {'Data': 'Test',
#  'GridSearch': True,
#  'MAE': 0.1959054450977505,
#  'MSE': 1.135539812545749,
#  'Name': 'Random Forest',
#  'R2': -1.413336503790498,
#  'RMSE': 1.0656171040977847}
# ['model/rf.model']

# %%
# Score sur la prédiction des données de train avec Random Forest
y_pred_train_gd_random_forest = rf_grid.predict(X_train_scaled)


mse_train_gd_random_forest = mean_squared_error(y_pred_train_gd_random_forest, y_train_scaled)
mae_train_gd_random_forest = mean_absolute_error(y_pred_train_gd_random_forest, y_train_scaled)
rmse_train_gd_random_forest = root_mean_squared_error(y_pred_train_gd_random_forest, y_train_scaled)
r2_train_gd_random_forest = r2_score(y_pred_train_gd_random_forest, y_train_scaled)


# Calcul des scores
random_forest_train_gd_score_pred = {
    "Name": "Random Forest",
    "Data": "Train",
    "GridSearch": True,
    "MSE": mse_train_gd_random_forest,
    "MAE": mae_train_gd_random_forest,
    "RMSE": rmse_train_gd_random_forest,
    "R2": r2_train_gd_random_forest
}

pprint(random_forest_train_gd_score_pred)
# Out:
# {'Data': 'Train',
#  'GridSearch': True,
#  'MAE': 0.09777225707456916,
#  'MSE': 0.11130168377056747,
#  'Name': 'Random Forest',
#  'R2': 0.8361247475538915,
#  'RMSE': 0.3336190698544786}

# %%
plt.bar(range(len(rf_best_model.feature_importances_)), rf_best_model.feature_importances_)
plt.show()

# %% [markdown]
# Xgboost

# %%
# XGBOOST avec GridSearchCV

params = {
    'n_estimators': [200, 300],
    'max_depth': [3, 5, 7],
    'learning_rate': [0.01, 0.05, 0.1],
    'min_child_weight': [1, 3, 5],
    'colsample_bytree': [0.8, 0.9]
}

xgb_grid = GridSearchCV(xgboost, 
                    params, 
                    cv=5,
                    scoring="r2"
                   )

xgb_grid.fit(X_train_scaled, y_train_scaled)
print(f"Best params: {grid.best_params_}")

# Tous les scores
scores_df = pd.DataFrame(xgb_grid.cv_results_)

y_pred_test_gd_xgboost = xgb_grid.predict(X_test_scaled)

mse_test_gd_xgboost = mean_squared_error(y_pred_test_gd_xgboost, y_test_scaled)
mae_test_gd_xgboost = mean_absolute_error(y_pred_test_gd_xgboost, y_test_scaled)
rmse_test_gd_xgboost = root_mean_squared_error(y_pred_test_gd_xgboost, y_test_scaled)
r2_test_gd_xgboost = r2_score(y_pred_test_gd_xgboost, y_test_scaled)


# Calcul des scores
xgb_test_gd_score_pred = {
    "Name": "Xgboost",
    "Data": "Test",
    "GridSearch": True,
    "MSE": mse_test_gd_xgboost,
    "MAE": mae_test_gd_xgboost,
    "RMSE": rmse_test_gd_xgboost,
    "R2": r2_test_gd_xgboost
}

pprint(xgb_test_gd_score_pred)


# Sauvegarde du model
xgb_best_model = xgb_grid.best_estimator_
joblib.dump(xgb_best_model, 'model/xgb.model')
# Out:
# Best params: {'C': 10, 'epsilon': 0.1, 'gamma': 'scale', 'kernel': 'rbf'}
# {'Data': 'Test',
#  'GridSearch': True,
#  'MAE': 0.21615644313978566,
#  'MSE': 1.0644898580111934,
#  'Name': 'Xgboost',
#  'R2': -0.7113737814972811,
#  'RMSE': 1.0317411778208687}
# ['model/xgb.model']

# %%
# Score sur la prédiction des données de train avec Xgboost
y_pred_train_gd_xgboost = xgb_grid.predict(X_train_scaled)


mse_train_gd_xgboost = mean_squared_error(y_pred_train_gd_xgboost, y_train_scaled)
mae_train_gd_xgboost = mean_absolute_error(y_pred_train_gd_xgboost, y_train_scaled)
rmse_train_gd_xgboost = root_mean_squared_error(y_pred_train_gd_xgboost, y_train_scaled)
r2_train_gd_xgboost = r2_score(y_pred_train_gd_xgboost, y_train_scaled)


# Calcul des scores
xgboost_train_gd_score_pred = {
    "Name": "Xgboost",
    "Data": "Train",
    "GridSearch": True,
    "MSE": mse_train_gd_xgboost,
    "MAE": mae_train_gd_xgboost,
    "RMSE": rmse_train_gd_xgboost,
    "R2": r2_train_gd_xgboost
}

pprint(xgboost_train_gd_score_pred)
# Out:
# {'Data': 'Train',
#  'GridSearch': True,
#  'MAE': 0.11393542662027019,
#  'MSE': 0.04345268674162629,
#  'Name': 'Xgboost',
#  'R2': 0.9504153394661078,
#  'RMSE': 0.20845308043208738}

# %%
plt.bar(range(len(xgb_best_model.feature_importances_)), xgb_best_model.feature_importances_)
plt.show()

# %% [markdown]
# ### Prediction sur les données d'entraînement

# %%
all_scores = pd.DataFrame(
    [dummy_test_score,
     dummy_train_score,
    linear_regression_test_pred_score,
    linear_regression_train_pred_score,
    svr_test_score_pred,
    svr_train_score_pred,
    random_forest_test_score_pred,
    random_forest_train_score_pred,
    lasso_test_score_pred,
    lasso_train_score_pred,
    ridge_test_score_pred,
    ridge_train_score_pred,
    xgboost_test_score_pred,
    xgboost_train_score_pred,
    linear_regression_test_gd_score_pred,
    linear_regression_train_gd_score_pred,
    lasso_test_gd_score_pred,
    lasso_train_gd_score_pred,
    ridge_test_gd_score_pred,
    ridge_train_gd_score_pred,
    svr_test_gd_score_pred,
    svr_train_gd_score_pred,
    random_forest_test_gd_score_pred,
    random_forest_train_gd_score_pred,
    xgb_test_gd_score_pred,
    xgboost_train_gd_score_pred
    ])

# %%
all_scores
# Out:
#                  Name   Data  GridSearch           MSE        MAE        RMSE  \
# 0               Dummy   Test       False      1.854465   0.535933    1.361788
# 1               Dummy  Train       False      1.000000   0.521510    1.000000
# 2   Linear Regression   Test       False  13381.037439  21.582206  115.676434
# 3   Linear Regression  Train       False      0.058894   0.133628    0.242680
# 4                 SVR   Test       False      1.283704   0.249016    1.133007
# 5                 SVR  Train       False      0.331041   0.211446    0.575361
# 6       Random Forest   Tets       False      1.174366   0.199804    1.083682
# 7       Random Forest  Train       False      0.045621   0.069214    0.213592
# 8               Lasso   Test       False      1.183479   0.208465    1.087878
# 9               Lasso  Train       False      0.152732   0.172749    0.390810
# 10              Ridge   Test       False      0.963549   0.268343    0.981605
# 11              Ridge  Train       False      0.060667   0.137678    0.246307
# 12            Xgboost   Test       False      1.172655   0.223035    1.082892
# 13            Xgboost  Train       False      0.001910   0.029811    0.043698
# 14  Linear Regression   Test        True      1.198384   0.519300    1.094707
# 15  Linear Regression  Train        True      0.299481   0.470664    0.547248
# 16              Lasso   Test        True      1.202928   0.205508    1.096781
# 17              Lasso  Train        True      0.299481   0.470664    0.547248
# 18              Ridge   Test        True      1.098275   0.217297    1.047986
# 19              Ridge  Train        True      0.099435   0.152711    0.315333
# 20                SVR   Test        True      1.210362   0.206209    1.100165
# 21                SVR  Train        True      0.169131   0.165990    0.411255
# 22      Random Forest   Test        True      1.135540   0.195905    1.065617
# 23      Random Forest  Train        True      0.111302   0.097772    0.333619
# 24            Xgboost   Test        True      1.064490   0.216156    1.031741
# 25            Xgboost  Train        True      0.043453   0.113935    0.208453
#
#           R2
# 0   0.000000
# 1   0.000000
# 2  -0.005509
# 3   0.937421
# 4  -4.493610
# 5   0.173142
# 6  -1.807959
# 7   0.939231
# 8  -1.392603
# 9   0.819214
# 10 -0.578378
# 11  0.934785
# 12 -0.879067
# 13  0.998065
# 14 -2.290290
# 15  0.473039
# 16 -1.475779
# 17  0.473039
# 18 -1.050787
# 19  0.886383
# 20 -1.795609
# 21  0.760497
# 22 -1.413337
# 23  0.836125
# 24 -0.711374
# 25  0.950415

# %%
X_train.columns.values
# Out:
# array(['DataYear', 'BuildingType', 'PrimaryPropertyType', 'ZipCode',
#        'CouncilDistrictCode', 'Neighborhood', 'YearBuilt',
#        'NumberofBuildings', 'NumberofFloors', 'PropertyGFATotal',
#        'PropertyGFAParking', 'ListOfAllPropertyUseTypes',
#        'LargestPropertyUseType', 'SecondLargestPropertyUseType',
#        'ThirdLargestPropertyUseType', 'SteamUsekBtu', 'NaturalGasTherms',
#        'DefaultData', 'ComplianceStatus'], dtype=object)

# %%
X_train.dtypes
# Out:
# DataYear                          int64
# BuildingType                     object
# PrimaryPropertyType              object
# ZipCode                         float64
# CouncilDistrictCode               int64
# Neighborhood                     object
# YearBuilt                         int64
# NumberofBuildings               float64
# NumberofFloors                    int64
# PropertyGFATotal                  int64
# PropertyGFAParking                int64
# ListOfAllPropertyUseTypes        object
# LargestPropertyUseType           object
# SecondLargestPropertyUseType     object
# ThirdLargestPropertyUseType      object
# SteamUsekBtu                    float64
# NaturalGasTherms                float64
# DefaultData                        bool
# ComplianceStatus                 object
# dtype: object
